# %% [markdown]
# # EVS-POT
# Use a function to map the (DH0, n_sigma) to 1D and estimate the probability.

# %% [markdown]
# ## Get data (no joint run for bf)

# %%
import os
import pandas as pd
import numpy as np
data_dir = '/cosma8/data/do012/dc-he4/analysis'

datadict = {}
for lc in range(1728):
    lc00 = f'{lc:04d}'

    filename = f'{data_dir}/lc{lc00}/bf_mcmc_scatter_random.csv'

    # check if file exists
    if os.path.exists(filename):
        df = pd.read_csv(filename)

        # save to df
        if 'ubf' not in list(datadict.keys()):  # dict.keys() is of type dict_keys
            for key in df.keys():           # load all data
                datadict[key] = df[key]

            length = len(df[key])           # register lightcone number
            datadict['Lightcone'] = np.full(length, lc)
        else:
            for key in df.keys():           # load all data
                datadict[key] = np.concatenate((datadict[key], df[key]))

            length = len(df[key])           # register lightcone number
            datadict['Lightcone'] = np.concatenate((datadict['Lightcone'], np.full(length, lc)))

    else:
        print(lc00, 'bf_mcmc_scatter_random.csv not found.')
        continue
    
data = pd.DataFrame(datadict)

data
# Out:
# 0341 bf_mcmc_scatter_random.csv not found.
# 0342 bf_mcmc_scatter_random.csv not found.
# 0343 bf_mcmc_scatter_random.csv not found.
# 0344 bf_mcmc_scatter_random.csv not found.
# 0345 bf_mcmc_scatter_random.csv not found.
# 0346 bf_mcmc_scatter_random.csv not found.
# 0347 bf_mcmc_scatter_random.csv not found.
# 0348 bf_mcmc_scatter_random.csv not found.
# 0349 bf_mcmc_scatter_random.csv not found.
# 0350 bf_mcmc_scatter_random.csv not found.
# 0351 bf_mcmc_scatter_random.csv not found.
# 0352 bf_mcmc_scatter_random.csv not found.
# 0353 bf_mcmc_scatter_random.csv not found.
# 0354 bf_mcmc_scatter_random.csv not found.
# 0355 bf_mcmc_scatter_random.csv not found.
# 0356 bf_mcmc_scatter_random.csv not found.
# 0357 bf_mcmc_scatter_random.csv not found.
# 0358 bf_mcmc_scatter_random.csv not found.
# 0359 bf_mcmc_scatter_random.csv not found.
# 0360 bf_mcmc_scatter_random.csv not found.
# 0361 bf_mcmc_scatter_random.csv not found.
# 0362 bf_mcmc_scatter_random.csv not found.
# 0363 bf_mcmc_scatter_random.csv not found.
# 0364 bf_mcmc_scatter_random.csv not found.
# 0365 bf_mcmc_scatter_random.csv not found.
# 0366 bf_mcmc_scatter_random.csv not found.
# 0367 bf_mcmc_scatter_random.csv not found.
# 0368 bf_mcmc_scatter_random.csv not found.
# 0369 bf_mcmc_scatter_random.csv not found.
# 0370 bf_mcmc_scatter_random.csv not found.
# 0371 bf_mcmc_scatter_random.csv not found.
# 0372 bf_mcmc_scatter_random.csv not found.
# 0373 bf_mcmc_scatter_random.csv not found.
# 0374 bf_mcmc_scatter_random.csv not found.
# 0375 bf_mcmc_scatter_random.csv not found.
# 0376 bf_mcmc_scatter_random.csv not found.
# 0377 bf_mcmc_scatter_random.csv not found.
# 0378 bf_mcmc_scatter_random.csv not found.
# 0379 bf_mcmc_scatter_random.csv not found.
# 0380 bf_mcmc_scatter_random.csv not found.
# 0381 bf_mcmc_scatter_random.csv not found.
# 0382 bf_mcmc_scatter_random.csv not found.
# 0383 bf_mcmc_scatter_random.csv not found.
# 0384 bf_mcmc_scatter_random.csv not found.
# 0385 bf_mcmc_scatter_random.csv not found.
# 0386 bf_mcmc_scatter_random.csv not found.
# 0387 bf_mcmc_scatter_random.csv not found.
# 0388 bf_mcmc_scatter_random.csv not found.
# 0389 bf_mcmc_scatter_random.csv not found.
# 0390 bf_mcmc_scatter_random.csv not found.
# 0391 bf_mcmc_scatter_random.csv not found.
# 0392 bf_mcmc_scatter_random.csv not found.
# 0393 bf_mcmc_scatter_random.csv not found.
# 0394 bf_mcmc_scatter_random.csv not found.
# 0395 bf_mcmc_scatter_random.csv not found.
# 0396 bf_mcmc_scatter_random.csv not found.
# 0397 bf_mcmc_scatter_random.csv not found.
# 0398 bf_mcmc_scatter_random.csv not found.
# 0399 bf_mcmc_scatter_random.csv not found.
# 0400 bf_mcmc_scatter_random.csv not found.
# 0401 bf_mcmc_scatter_random.csv not found.
# 0402 bf_mcmc_scatter_random.csv not found.
# 0403 bf_mcmc_scatter_random.csv not found.
# 0404 bf_mcmc_scatter_random.csv not found.
# 0405 bf_mcmc_scatter_random.csv not found.
# 0406 bf_mcmc_scatter_random.csv not found.
# 0407 bf_mcmc_scatter_random.csv not found.
# 0408 bf_mcmc_scatter_random.csv not found.
# 0409 bf_mcmc_scatter_random.csv not found.
# 0410 bf_mcmc_scatter_random.csv not found.
# 0411 bf_mcmc_scatter_random.csv not found.
# 0412 bf_mcmc_scatter_random.csv not found.
# 0413 bf_mcmc_scatter_random.csv not found.
# 0414 bf_mcmc_scatter_random.csv not found.
# 0415 bf_mcmc_scatter_random.csv not found.
# 0416 bf_mcmc_scatter_random.csv not found.
# 0417 bf_mcmc_scatter_random.csv not found.
# 0418 bf_mcmc_scatter_random.csv not found.
# 0419 bf_mcmc_scatter_random.csv not found.
# 0420 bf_mcmc_scatter_random.csv not found.
# 0421 bf_mcmc_scatter_random.csv not found.
# 0422 bf_mcmc_scatter_random.csv not found.
# 0423 bf_mcmc_scatter_random.csv not found.
# 0424 bf_mcmc_scatter_random.csv not found.
# 0425 bf_mcmc_scatter_random.csv not found.
# 0426 bf_mcmc_scatter_random.csv not found.
# 0427 bf_mcmc_scatter_random.csv not found.
# 0428 bf_mcmc_scatter_random.csv not found.
# 0429 bf_mcmc_scatter_random.csv not found.
# 0430 bf_mcmc_scatter_random.csv not found.
# 0431 bf_mcmc_scatter_random.csv not found.
# 0432 bf_mcmc_scatter_random.csv not found.
# 0433 bf_mcmc_scatter_random.csv not found.
# 0434 bf_mcmc_scatter_random.csv not found.
# 0435 bf_mcmc_scatter_random.csv not found.
# 0436 bf_mcmc_scatter_random.csv not found.
# 0437 bf_mcmc_scatter_random.csv not found.
# 0438 bf_mcmc_scatter_random.csv not found.
# 0439 bf_mcmc_scatter_random.csv not found.
# 0440 bf_mcmc_scatter_random.csv not found.
# 0441 bf_mcmc_scatter_random.csv not found.
# 0442 bf_mcmc_scatter_random.csv not found.
# 0443 bf_mcmc_scatter_random.csv not found.
# 0444 bf_mcmc_scatter_random.csv not found.
# 0445 bf_mcmc_scatter_random.csv not found.
# 0446 bf_mcmc_scatter_random.csv not found.
# 0447 bf_mcmc_scatter_random.csv not found.
# 0448 bf_mcmc_scatter_random.csv not found.
# 0449 bf_mcmc_scatter_random.csv not found.
# 0450 bf_mcmc_scatter_random.csv not found.
# 0451 bf_mcmc_scatter_random.csv not found.
# 0452 bf_mcmc_scatter_random.csv not found.
# 0453 bf_mcmc_scatter_random.csv not found.
# 0454 bf_mcmc_scatter_random.csv not found.
# 0455 bf_mcmc_scatter_random.csv not found.
# 0456 bf_mcmc_scatter_random.csv not found.
# 0457 bf_mcmc_scatter_random.csv not found.
# 0458 bf_mcmc_scatter_random.csv not found.
# 0459 bf_mcmc_scatter_random.csv not found.
# 0460 bf_mcmc_scatter_random.csv not found.
# 0461 bf_mcmc_scatter_random.csv not found.
# 0462 bf_mcmc_scatter_random.csv not found.
# 0463 bf_mcmc_scatter_random.csv not found.
# 0464 bf_mcmc_scatter_random.csv not found.
# 0465 bf_mcmc_scatter_random.csv not found.
# 0466 bf_mcmc_scatter_random.csv not found.
# 0467 bf_mcmc_scatter_random.csv not found.
# 0468 bf_mcmc_scatter_random.csv not found.
# 0469 bf_mcmc_scatter_random.csv not found.
# 0470 bf_mcmc_scatter_random.csv not found.
# 0471 bf_mcmc_scatter_random.csv not found.
# 0472 bf_mcmc_scatter_random.csv not found.
# 0473 bf_mcmc_scatter_random.csv not found.
# 0474 bf_mcmc_scatter_random.csv not found.
# 0475 bf_mcmc_scatter_random.csv not found.
# 0476 bf_mcmc_scatter_random.csv not found.
# 0477 bf_mcmc_scatter_random.csv not found.
# 0478 bf_mcmc_scatter_random.csv not found.
# 0479 bf_mcmc_scatter_random.csv not found.
# 0480 bf_mcmc_scatter_random.csv not found.
# 0481 bf_mcmc_scatter_random.csv not found.
# 0482 bf_mcmc_scatter_random.csv not found.
# 0483 bf_mcmc_scatter_random.csv not found.
# 0484 bf_mcmc_scatter_random.csv not found.
# 0485 bf_mcmc_scatter_random.csv not found.
# 0486 bf_mcmc_scatter_random.csv not found.
# 0487 bf_mcmc_scatter_random.csv not found.
# 0488 bf_mcmc_scatter_random.csv not found.
# 0489 bf_mcmc_scatter_random.csv not found.
# 0490 bf_mcmc_scatter_random.csv not found.
# 0491 bf_mcmc_scatter_random.csv not found.
# 0492 bf_mcmc_scatter_random.csv not found.
# 0493 bf_mcmc_scatter_random.csv not found.
# 0494 bf_mcmc_scatter_random.csv not found.
# 0495 bf_mcmc_scatter_random.csv not found.
# 0496 bf_mcmc_scatter_random.csv not found.
# 0497 bf_mcmc_scatter_random.csv not found.
# 0498 bf_mcmc_scatter_random.csv not found.
# 0499 bf_mcmc_scatter_random.csv not found.
# 0528 bf_mcmc_scatter_random.csv not found.
# 0529 bf_mcmc_scatter_random.csv not found.
# 0530 bf_mcmc_scatter_random.csv not found.
# 0531 bf_mcmc_scatter_random.csv not found.
# 0532 bf_mcmc_scatter_random.csv not found.
# 0533 bf_mcmc_scatter_random.csv not found.
# 0534 bf_mcmc_scatter_random.csv not found.
# 0535 bf_mcmc_scatter_random.csv not found.
# 0536 bf_mcmc_scatter_random.csv not found.
# 0537 bf_mcmc_scatter_random.csv not found.
# 0538 bf_mcmc_scatter_random.csv not found.
# 0539 bf_mcmc_scatter_random.csv not found.
# 0540 bf_mcmc_scatter_random.csv not found.
# 0541 bf_mcmc_scatter_random.csv not found.
# 0542 bf_mcmc_scatter_random.csv not found.
# 0543 bf_mcmc_scatter_random.csv not found.
# 0544 bf_mcmc_scatter_random.csv not found.
# 0545 bf_mcmc_scatter_random.csv not found.
# 0546 bf_mcmc_scatter_random.csv not found.
# 0547 bf_mcmc_scatter_random.csv not found.
# 0548 bf_mcmc_scatter_random.csv not found.
# 0549 bf_mcmc_scatter_random.csv not found.
# 0550 bf_mcmc_scatter_random.csv not found.
# 0551 bf_mcmc_scatter_random.csv not found.
# 0552 bf_mcmc_scatter_random.csv not found.
# 0553 bf_mcmc_scatter_random.csv not found.
# 0554 bf_mcmc_scatter_random.csv not found.
# 0555 bf_mcmc_scatter_random.csv not found.
# 0556 bf_mcmc_scatter_random.csv not found.
# 0557 bf_mcmc_scatter_random.csv not found.
# 0558 bf_mcmc_scatter_random.csv not found.
# 0559 bf_mcmc_scatter_random.csv not found.
# 0560 bf_mcmc_scatter_random.csv not found.
# 0561 bf_mcmc_scatter_random.csv not found.
# 0562 bf_mcmc_scatter_random.csv not found.
# 0563 bf_mcmc_scatter_random.csv not found.
# 0564 bf_mcmc_scatter_random.csv not found.
# 0565 bf_mcmc_scatter_random.csv not found.
# 0566 bf_mcmc_scatter_random.csv not found.
# 0567 bf_mcmc_scatter_random.csv not found.
# 0568 bf_mcmc_scatter_random.csv not found.
# 0569 bf_mcmc_scatter_random.csv not found.
# 0570 bf_mcmc_scatter_random.csv not found.
# 0571 bf_mcmc_scatter_random.csv not found.
# 0572 bf_mcmc_scatter_random.csv not found.
# 0573 bf_mcmc_scatter_random.csv not found.
# 0574 bf_mcmc_scatter_random.csv not found.
# 0575 bf_mcmc_scatter_random.csv not found.
# 0576 bf_mcmc_scatter_random.csv not found.
# 0577 bf_mcmc_scatter_random.csv not found.
# 0578 bf_mcmc_scatter_random.csv not found.
# 0579 bf_mcmc_scatter_random.csv not found.
# 0580 bf_mcmc_scatter_random.csv not found.
# 0581 bf_mcmc_scatter_random.csv not found.
# 0582 bf_mcmc_scatter_random.csv not found.
# 0583 bf_mcmc_scatter_random.csv not found.
# 0584 bf_mcmc_scatter_random.csv not found.
# 0585 bf_mcmc_scatter_random.csv not found.
# 0586 bf_mcmc_scatter_random.csv not found.
# 0587 bf_mcmc_scatter_random.csv not found.
# 0588 bf_mcmc_scatter_random.csv not found.
# 0589 bf_mcmc_scatter_random.csv not found.
# 0590 bf_mcmc_scatter_random.csv not found.
# 0591 bf_mcmc_scatter_random.csv not found.
# 0592 bf_mcmc_scatter_random.csv not found.
# 0593 bf_mcmc_scatter_random.csv not found.
# 0594 bf_mcmc_scatter_random.csv not found.
# 0595 bf_mcmc_scatter_random.csv not found.
# 0596 bf_mcmc_scatter_random.csv not found.
# 0597 bf_mcmc_scatter_random.csv not found.
# 0598 bf_mcmc_scatter_random.csv not found.
# 0599 bf_mcmc_scatter_random.csv not found.
# 0628 bf_mcmc_scatter_random.csv not found.
# 0629 bf_mcmc_scatter_random.csv not found.
# 0630 bf_mcmc_scatter_random.csv not found.
# 0631 bf_mcmc_scatter_random.csv not found.
# 0632 bf_mcmc_scatter_random.csv not found.
# 0633 bf_mcmc_scatter_random.csv not found.
# 0634 bf_mcmc_scatter_random.csv not found.
# 0635 bf_mcmc_scatter_random.csv not found.
# 0636 bf_mcmc_scatter_random.csv not found.
# 0637 bf_mcmc_scatter_random.csv not found.
# 0638 bf_mcmc_scatter_random.csv not found.
# 0639 bf_mcmc_scatter_random.csv not found.
# 0640 bf_mcmc_scatter_random.csv not found.
# 0641 bf_mcmc_scatter_random.csv not found.
# 0642 bf_mcmc_scatter_random.csv not found.
# 0643 bf_mcmc_scatter_random.csv not found.
# 0644 bf_mcmc_scatter_random.csv not found.
# 0645 bf_mcmc_scatter_random.csv not found.
# 0646 bf_mcmc_scatter_random.csv not found.
# 0647 bf_mcmc_scatter_random.csv not found.
# 0648 bf_mcmc_scatter_random.csv not found.
# 0649 bf_mcmc_scatter_random.csv not found.
# 0650 bf_mcmc_scatter_random.csv not found.
# 0651 bf_mcmc_scatter_random.csv not found.
# 0652 bf_mcmc_scatter_random.csv not found.
# 0653 bf_mcmc_scatter_random.csv not found.
# 0654 bf_mcmc_scatter_random.csv not found.
# 0655 bf_mcmc_scatter_random.csv not found.
# 0656 bf_mcmc_scatter_random.csv not found.
# 0657 bf_mcmc_scatter_random.csv not found.
# 0658 bf_mcmc_scatter_random.csv not found.
# 0659 bf_mcmc_scatter_random.csv not found.
# 0660 bf_mcmc_scatter_random.csv not found.
# 0661 bf_mcmc_scatter_random.csv not found.
# 0662 bf_mcmc_scatter_random.csv not found.
# 0663 bf_mcmc_scatter_random.csv not found.
# 0664 bf_mcmc_scatter_random.csv not found.
# 0665 bf_mcmc_scatter_random.csv not found.
# 0666 bf_mcmc_scatter_random.csv not found.
# 0667 bf_mcmc_scatter_random.csv not found.
# 0668 bf_mcmc_scatter_random.csv not found.
# 0669 bf_mcmc_scatter_random.csv not found.
# 0670 bf_mcmc_scatter_random.csv not found.
# 0671 bf_mcmc_scatter_random.csv not found.
# 0672 bf_mcmc_scatter_random.csv not found.
# 0673 bf_mcmc_scatter_random.csv not found.
# 0674 bf_mcmc_scatter_random.csv not found.
# 0675 bf_mcmc_scatter_random.csv not found.
# 0676 bf_mcmc_scatter_random.csv not found.
# 0677 bf_mcmc_scatter_random.csv not found.
# 0678 bf_mcmc_scatter_random.csv not found.
# 0679 bf_mcmc_scatter_random.csv not found.
# 0680 bf_mcmc_scatter_random.csv not found.
# 0681 bf_mcmc_scatter_random.csv not found.
# 0682 bf_mcmc_scatter_random.csv not found.
# 0683 bf_mcmc_scatter_random.csv not found.
# 0684 bf_mcmc_scatter_random.csv not found.
# 0685 bf_mcmc_scatter_random.csv not found.
# 0686 bf_mcmc_scatter_random.csv not found.
# 0687 bf_mcmc_scatter_random.csv not found.
# 0688 bf_mcmc_scatter_random.csv not found.
# 0689 bf_mcmc_scatter_random.csv not found.
# 0690 bf_mcmc_scatter_random.csv not found.
# 0691 bf_mcmc_scatter_random.csv not found.
# 0692 bf_mcmc_scatter_random.csv not found.
# 0693 bf_mcmc_scatter_random.csv not found.
# 0694 bf_mcmc_scatter_random.csv not found.
# 0695 bf_mcmc_scatter_random.csv not found.
# 0696 bf_mcmc_scatter_random.csv not found.
# 0697 bf_mcmc_scatter_random.csv not found.
# 0698 bf_mcmc_scatter_random.csv not found.
# 0699 bf_mcmc_scatter_random.csv not found.
# 0728 bf_mcmc_scatter_random.csv not found.
# 0729 bf_mcmc_scatter_random.csv not found.
# 0730 bf_mcmc_scatter_random.csv not found.
# 0731 bf_mcmc_scatter_random.csv not found.
# 0732 bf_mcmc_scatter_random.csv not found.
# 0733 bf_mcmc_scatter_random.csv not found.
# 0734 bf_mcmc_scatter_random.csv not found.
# 0735 bf_mcmc_scatter_random.csv not found.
# 0736 bf_mcmc_scatter_random.csv not found.
# 0737 bf_mcmc_scatter_random.csv not found.
# 0738 bf_mcmc_scatter_random.csv not found.
# 0739 bf_mcmc_scatter_random.csv not found.
# 0740 bf_mcmc_scatter_random.csv not found.
# 0741 bf_mcmc_scatter_random.csv not found.
# 0742 bf_mcmc_scatter_random.csv not found.
# 0743 bf_mcmc_scatter_random.csv not found.
# 0744 bf_mcmc_scatter_random.csv not found.
# 0745 bf_mcmc_scatter_random.csv not found.
# 0746 bf_mcmc_scatter_random.csv not found.
# 0747 bf_mcmc_scatter_random.csv not found.
# 0748 bf_mcmc_scatter_random.csv not found.
# 0749 bf_mcmc_scatter_random.csv not found.
# 0750 bf_mcmc_scatter_random.csv not found.
# 0751 bf_mcmc_scatter_random.csv not found.
# 0752 bf_mcmc_scatter_random.csv not found.
# 0753 bf_mcmc_scatter_random.csv not found.
# 0754 bf_mcmc_scatter_random.csv not found.
# 0755 bf_mcmc_scatter_random.csv not found.
# 0756 bf_mcmc_scatter_random.csv not found.
# 0757 bf_mcmc_scatter_random.csv not found.
# 0758 bf_mcmc_scatter_random.csv not found.
# 0759 bf_mcmc_scatter_random.csv not found.
# 0760 bf_mcmc_scatter_random.csv not found.
# 0761 bf_mcmc_scatter_random.csv not found.
# 0762 bf_mcmc_scatter_random.csv not found.
# 0763 bf_mcmc_scatter_random.csv not found.
# 0764 bf_mcmc_scatter_random.csv not found.
# 0765 bf_mcmc_scatter_random.csv not found.
# 0766 bf_mcmc_scatter_random.csv not found.
# 0767 bf_mcmc_scatter_random.csv not found.
# 0768 bf_mcmc_scatter_random.csv not found.
# 0769 bf_mcmc_scatter_random.csv not found.
# 0770 bf_mcmc_scatter_random.csv not found.
# 0771 bf_mcmc_scatter_random.csv not found.
# 0772 bf_mcmc_scatter_random.csv not found.
# 0773 bf_mcmc_scatter_random.csv not found.
# 0774 bf_mcmc_scatter_random.csv not found.
# 0775 bf_mcmc_scatter_random.csv not found.
# 0776 bf_mcmc_scatter_random.csv not found.
# 0777 bf_mcmc_scatter_random.csv not found.
# 0778 bf_mcmc_scatter_random.csv not found.
# 0779 bf_mcmc_scatter_random.csv not found.
# 0780 bf_mcmc_scatter_random.csv not found.
# 0781 bf_mcmc_scatter_random.csv not found.
# 0782 bf_mcmc_scatter_random.csv not found.
# 0783 bf_mcmc_scatter_random.csv not found.
# 0784 bf_mcmc_scatter_random.csv not found.
# 0785 bf_mcmc_scatter_random.csv not found.
# 0786 bf_mcmc_scatter_random.csv not found.
# 0787 bf_mcmc_scatter_random.csv not found.
# 0788 bf_mcmc_scatter_random.csv not found.
# 0789 bf_mcmc_scatter_random.csv not found.
# 0790 bf_mcmc_scatter_random.csv not found.
# 0791 bf_mcmc_scatter_random.csv not found.
# 0792 bf_mcmc_scatter_random.csv not found.
# 0793 bf_mcmc_scatter_random.csv not found.
# 0794 bf_mcmc_scatter_random.csv not found.
# 0795 bf_mcmc_scatter_random.csv not found.
# 0796 bf_mcmc_scatter_random.csv not found.
# 0797 bf_mcmc_scatter_random.csv not found.
# 0798 bf_mcmc_scatter_random.csv not found.
# 0799 bf_mcmc_scatter_random.csv not found.
# 0828 bf_mcmc_scatter_random.csv not found.
# 0829 bf_mcmc_scatter_random.csv not found.
# 0830 bf_mcmc_scatter_random.csv not found.
# 0831 bf_mcmc_scatter_random.csv not found.
# 0832 bf_mcmc_scatter_random.csv not found.
# 0833 bf_mcmc_scatter_random.csv not found.
# 0834 bf_mcmc_scatter_random.csv not found.
# 0835 bf_mcmc_scatter_random.csv not found.
# 0836 bf_mcmc_scatter_random.csv not found.
# 0837 bf_mcmc_scatter_random.csv not found.
# 0838 bf_mcmc_scatter_random.csv not found.
# 0839 bf_mcmc_scatter_random.csv not found.
# 0840 bf_mcmc_scatter_random.csv not found.
# 0841 bf_mcmc_scatter_random.csv not found.
# 0842 bf_mcmc_scatter_random.csv not found.
# 0843 bf_mcmc_scatter_random.csv not found.
# 0844 bf_mcmc_scatter_random.csv not found.
# 0845 bf_mcmc_scatter_random.csv not found.
# 0846 bf_mcmc_scatter_random.csv not found.
# 0847 bf_mcmc_scatter_random.csv not found.
# 0848 bf_mcmc_scatter_random.csv not found.
# 0849 bf_mcmc_scatter_random.csv not found.
# 0850 bf_mcmc_scatter_random.csv not found.
# 0851 bf_mcmc_scatter_random.csv not found.
# 0852 bf_mcmc_scatter_random.csv not found.
# 0853 bf_mcmc_scatter_random.csv not found.
# 0854 bf_mcmc_scatter_random.csv not found.
# 0855 bf_mcmc_scatter_random.csv not found.
# 0856 bf_mcmc_scatter_random.csv not found.
# 0857 bf_mcmc_scatter_random.csv not found.
# 0858 bf_mcmc_scatter_random.csv not found.
# 0859 bf_mcmc_scatter_random.csv not found.
# 0860 bf_mcmc_scatter_random.csv not found.
# 0861 bf_mcmc_scatter_random.csv not found.
# 0862 bf_mcmc_scatter_random.csv not found.
# 0863 bf_mcmc_scatter_random.csv not found.
# 0864 bf_mcmc_scatter_random.csv not found.
# 0865 bf_mcmc_scatter_random.csv not found.
# 0866 bf_mcmc_scatter_random.csv not found.
# 0867 bf_mcmc_scatter_random.csv not found.
# 0868 bf_mcmc_scatter_random.csv not found.
# 0869 bf_mcmc_scatter_random.csv not found.
# 0870 bf_mcmc_scatter_random.csv not found.
# 0871 bf_mcmc_scatter_random.csv not found.
# 0872 bf_mcmc_scatter_random.csv not found.
# 0873 bf_mcmc_scatter_random.csv not found.
# 0874 bf_mcmc_scatter_random.csv not found.
# 0875 bf_mcmc_scatter_random.csv not found.
# 0876 bf_mcmc_scatter_random.csv not found.
# 0877 bf_mcmc_scatter_random.csv not found.
# 0878 bf_mcmc_scatter_random.csv not found.
# 0879 bf_mcmc_scatter_random.csv not found.
# 0880 bf_mcmc_scatter_random.csv not found.
# 0881 bf_mcmc_scatter_random.csv not found.
# 0882 bf_mcmc_scatter_random.csv not found.
# 0883 bf_mcmc_scatter_random.csv not found.
# 0884 bf_mcmc_scatter_random.csv not found.
# 0885 bf_mcmc_scatter_random.csv not found.
# 0886 bf_mcmc_scatter_random.csv not found.
# 0887 bf_mcmc_scatter_random.csv not found.
# 0888 bf_mcmc_scatter_random.csv not found.
# 0889 bf_mcmc_scatter_random.csv not found.
# 0890 bf_mcmc_scatter_random.csv not found.
# 0891 bf_mcmc_scatter_random.csv not found.
# 0892 bf_mcmc_scatter_random.csv not found.
# 0893 bf_mcmc_scatter_random.csv not found.
# 0894 bf_mcmc_scatter_random.csv not found.
# 0895 bf_mcmc_scatter_random.csv not found.
# 0896 bf_mcmc_scatter_random.csv not found.
# 0897 bf_mcmc_scatter_random.csv not found.
# 0898 bf_mcmc_scatter_random.csv not found.
# 0899 bf_mcmc_scatter_random.csv not found.
# 0900 bf_mcmc_scatter_random.csv not found.
# 0901 bf_mcmc_scatter_random.csv not found.
# 0902 bf_mcmc_scatter_random.csv not found.
# 0903 bf_mcmc_scatter_random.csv not found.
# 0904 bf_mcmc_scatter_random.csv not found.
# 0905 bf_mcmc_scatter_random.csv not found.
# 0906 bf_mcmc_scatter_random.csv not found.
# 0907 bf_mcmc_scatter_random.csv not found.
# 0908 bf_mcmc_scatter_random.csv not found.
# 0909 bf_mcmc_scatter_random.csv not found.
# 0910 bf_mcmc_scatter_random.csv not found.
# 0911 bf_mcmc_scatter_random.csv not found.
# 0912 bf_mcmc_scatter_random.csv not found.
# 0913 bf_mcmc_scatter_random.csv not found.
# 0914 bf_mcmc_scatter_random.csv not found.
# 0915 bf_mcmc_scatter_random.csv not found.
# 0916 bf_mcmc_scatter_random.csv not found.
# 0917 bf_mcmc_scatter_random.csv not found.
# 0918 bf_mcmc_scatter_random.csv not found.
# 0919 bf_mcmc_scatter_random.csv not found.
# 0920 bf_mcmc_scatter_random.csv not found.
# 0921 bf_mcmc_scatter_random.csv not found.
# 0922 bf_mcmc_scatter_random.csv not found.
# 0923 bf_mcmc_scatter_random.csv not found.
# 0924 bf_mcmc_scatter_random.csv not found.
# 0925 bf_mcmc_scatter_random.csv not found.
# 0926 bf_mcmc_scatter_random.csv not found.
# 0927 bf_mcmc_scatter_random.csv not found.
# 0928 bf_mcmc_scatter_random.csv not found.
# 0929 bf_mcmc_scatter_random.csv not found.
# 0930 bf_mcmc_scatter_random.csv not found.
# 0931 bf_mcmc_scatter_random.csv not found.
# 0932 bf_mcmc_scatter_random.csv not found.
# 0933 bf_mcmc_scatter_random.csv not found.
# 0934 bf_mcmc_scatter_random.csv not found.
# 0935 bf_mcmc_scatter_random.csv not found.
# 0936 bf_mcmc_scatter_random.csv not found.
# 0937 bf_mcmc_scatter_random.csv not found.
# 0938 bf_mcmc_scatter_random.csv not found.
# 0939 bf_mcmc_scatter_random.csv not found.
# 0940 bf_mcmc_scatter_random.csv not found.
# 0941 bf_mcmc_scatter_random.csv not found.
# 0942 bf_mcmc_scatter_random.csv not found.
# 0943 bf_mcmc_scatter_random.csv not found.
# 0944 bf_mcmc_scatter_random.csv not found.
# 0945 bf_mcmc_scatter_random.csv not found.
# 0946 bf_mcmc_scatter_random.csv not found.
# 0947 bf_mcmc_scatter_random.csv not found.
# 0948 bf_mcmc_scatter_random.csv not found.
# 0949 bf_mcmc_scatter_random.csv not found.
# 0950 bf_mcmc_scatter_random.csv not found.
# 0951 bf_mcmc_scatter_random.csv not found.
# 0952 bf_mcmc_scatter_random.csv not found.
# 0953 bf_mcmc_scatter_random.csv not found.
# 0954 bf_mcmc_scatter_random.csv not found.
# 0955 bf_mcmc_scatter_random.csv not found.
# 0956 bf_mcmc_scatter_random.csv not found.
# 0957 bf_mcmc_scatter_random.csv not found.
# 0958 bf_mcmc_scatter_random.csv not found.
# 0959 bf_mcmc_scatter_random.csv not found.
# 0960 bf_mcmc_scatter_random.csv not found.
# 0961 bf_mcmc_scatter_random.csv not found.
# 0962 bf_mcmc_scatter_random.csv not found.
# 0963 bf_mcmc_scatter_random.csv not found.
# 0964 bf_mcmc_scatter_random.csv not found.
# 0965 bf_mcmc_scatter_random.csv not found.
# 0966 bf_mcmc_scatter_random.csv not found.
# 0967 bf_mcmc_scatter_random.csv not found.
# 0968 bf_mcmc_scatter_random.csv not found.
# 0969 bf_mcmc_scatter_random.csv not found.
# 0970 bf_mcmc_scatter_random.csv not found.
# 0971 bf_mcmc_scatter_random.csv not found.
# 0972 bf_mcmc_scatter_random.csv not found.
# 0973 bf_mcmc_scatter_random.csv not found.
# 0974 bf_mcmc_scatter_random.csv not found.
# 0975 bf_mcmc_scatter_random.csv not found.
# 0976 bf_mcmc_scatter_random.csv not found.
# 0977 bf_mcmc_scatter_random.csv not found.
# 0978 bf_mcmc_scatter_random.csv not found.
# 0979 bf_mcmc_scatter_random.csv not found.
# 0980 bf_mcmc_scatter_random.csv not found.
# 0981 bf_mcmc_scatter_random.csv not found.
# 0982 bf_mcmc_scatter_random.csv not found.
# 0983 bf_mcmc_scatter_random.csv not found.
# 0984 bf_mcmc_scatter_random.csv not found.
# 0985 bf_mcmc_scatter_random.csv not found.
# 0986 bf_mcmc_scatter_random.csv not found.
# 0987 bf_mcmc_scatter_random.csv not found.
# 0988 bf_mcmc_scatter_random.csv not found.
# 0989 bf_mcmc_scatter_random.csv not found.
# 0990 bf_mcmc_scatter_random.csv not found.
# 0991 bf_mcmc_scatter_random.csv not found.
# 0992 bf_mcmc_scatter_random.csv not found.
# 0993 bf_mcmc_scatter_random.csv not found.
# 0994 bf_mcmc_scatter_random.csv not found.
# 0995 bf_mcmc_scatter_random.csv not found.
# 0996 bf_mcmc_scatter_random.csv not found.
# 0997 bf_mcmc_scatter_random.csv not found.
# 0998 bf_mcmc_scatter_random.csv not found.
# 0999 bf_mcmc_scatter_random.csv not found.
# 1000 bf_mcmc_scatter_random.csv not found.
# 1001 bf_mcmc_scatter_random.csv not found.
# 1002 bf_mcmc_scatter_random.csv not found.
# 1003 bf_mcmc_scatter_random.csv not found.
# 1004 bf_mcmc_scatter_random.csv not found.
# 1005 bf_mcmc_scatter_random.csv not found.
# 1006 bf_mcmc_scatter_random.csv not found.
# 1007 bf_mcmc_scatter_random.csv not found.
# 1008 bf_mcmc_scatter_random.csv not found.
# 1009 bf_mcmc_scatter_random.csv not found.
# 1010 bf_mcmc_scatter_random.csv not found.
# 1011 bf_mcmc_scatter_random.csv not found.
# 1012 bf_mcmc_scatter_random.csv not found.
# 1013 bf_mcmc_scatter_random.csv not found.
# 1014 bf_mcmc_scatter_random.csv not found.
# 1015 bf_mcmc_scatter_random.csv not found.
# 1016 bf_mcmc_scatter_random.csv not found.
# 1017 bf_mcmc_scatter_random.csv not found.
# 1018 bf_mcmc_scatter_random.csv not found.
# 1019 bf_mcmc_scatter_random.csv not found.
# 1020 bf_mcmc_scatter_random.csv not found.
# 1021 bf_mcmc_scatter_random.csv not found.
# 1022 bf_mcmc_scatter_random.csv not found.
# 1023 bf_mcmc_scatter_random.csv not found.
# 1024 bf_mcmc_scatter_random.csv not found.
# 1025 bf_mcmc_scatter_random.csv not found.
# 1026 bf_mcmc_scatter_random.csv not found.
# 1027 bf_mcmc_scatter_random.csv not found.
# 1028 bf_mcmc_scatter_random.csv not found.
# 1029 bf_mcmc_scatter_random.csv not found.
# 1030 bf_mcmc_scatter_random.csv not found.
# 1031 bf_mcmc_scatter_random.csv not found.
# 1032 bf_mcmc_scatter_random.csv not found.
# 1033 bf_mcmc_scatter_random.csv not found.
# 1034 bf_mcmc_scatter_random.csv not found.
# 1035 bf_mcmc_scatter_random.csv not found.
# 1036 bf_mcmc_scatter_random.csv not found.
# 1037 bf_mcmc_scatter_random.csv not found.
# 1038 bf_mcmc_scatter_random.csv not found.
# 1039 bf_mcmc_scatter_random.csv not found.
# 1040 bf_mcmc_scatter_random.csv not found.
# 1041 bf_mcmc_scatter_random.csv not found.
# 1042 bf_mcmc_scatter_random.csv not found.
# 1043 bf_mcmc_scatter_random.csv not found.
# 1044 bf_mcmc_scatter_random.csv not found.
# 1045 bf_mcmc_scatter_random.csv not found.
# 1046 bf_mcmc_scatter_random.csv not found.
# 1047 bf_mcmc_scatter_random.csv not found.
# 1048 bf_mcmc_scatter_random.csv not found.
# 1049 bf_mcmc_scatter_random.csv not found.
# 1050 bf_mcmc_scatter_random.csv not found.
# 1051 bf_mcmc_scatter_random.csv not found.
# 1052 bf_mcmc_scatter_random.csv not found.
# 1053 bf_mcmc_scatter_random.csv not found.
# 1054 bf_mcmc_scatter_random.csv not found.
# 1055 bf_mcmc_scatter_random.csv not found.
# 1056 bf_mcmc_scatter_random.csv not found.
# 1057 bf_mcmc_scatter_random.csv not found.
# 1058 bf_mcmc_scatter_random.csv not found.
# 1059 bf_mcmc_scatter_random.csv not found.
# 1060 bf_mcmc_scatter_random.csv not found.
# 1061 bf_mcmc_scatter_random.csv not found.
# 1062 bf_mcmc_scatter_random.csv not found.
# 1063 bf_mcmc_scatter_random.csv not found.
# 1064 bf_mcmc_scatter_random.csv not found.
# 1065 bf_mcmc_scatter_random.csv not found.
# 1066 bf_mcmc_scatter_random.csv not found.
# 1067 bf_mcmc_scatter_random.csv not found.
# 1068 bf_mcmc_scatter_random.csv not found.
# 1069 bf_mcmc_scatter_random.csv not found.
# 1070 bf_mcmc_scatter_random.csv not found.
# 1071 bf_mcmc_scatter_random.csv not found.
# 1072 bf_mcmc_scatter_random.csv not found.
# 1073 bf_mcmc_scatter_random.csv not found.
# 1074 bf_mcmc_scatter_random.csv not found.
# 1075 bf_mcmc_scatter_random.csv not found.
# 1076 bf_mcmc_scatter_random.csv not found.
# 1077 bf_mcmc_scatter_random.csv not found.
# 1078 bf_mcmc_scatter_random.csv not found.
# 1079 bf_mcmc_scatter_random.csv not found.
# 1080 bf_mcmc_scatter_random.csv not found.
# 1081 bf_mcmc_scatter_random.csv not found.
# 1082 bf_mcmc_scatter_random.csv not found.
# 1083 bf_mcmc_scatter_random.csv not found.
# 1084 bf_mcmc_scatter_random.csv not found.
# 1085 bf_mcmc_scatter_random.csv not found.
# 1086 bf_mcmc_scatter_random.csv not found.
# 1087 bf_mcmc_scatter_random.csv not found.
# 1088 bf_mcmc_scatter_random.csv not found.
# 1089 bf_mcmc_scatter_random.csv not found.
# 1090 bf_mcmc_scatter_random.csv not found.
# 1091 bf_mcmc_scatter_random.csv not found.
# 1092 bf_mcmc_scatter_random.csv not found.
# 1093 bf_mcmc_scatter_random.csv not found.
# 1094 bf_mcmc_scatter_random.csv not found.
# 1095 bf_mcmc_scatter_random.csv not found.
# 1096 bf_mcmc_scatter_random.csv not found.
# 1097 bf_mcmc_scatter_random.csv not found.
# 1098 bf_mcmc_scatter_random.csv not found.
# 1099 bf_mcmc_scatter_random.csv not found.
# 1100 bf_mcmc_scatter_random.csv not found.
# 1101 bf_mcmc_scatter_random.csv not found.
# 1102 bf_mcmc_scatter_random.csv not found.
# 1103 bf_mcmc_scatter_random.csv not found.
# 1104 bf_mcmc_scatter_random.csv not found.
# 1105 bf_mcmc_scatter_random.csv not found.
# 1106 bf_mcmc_scatter_random.csv not found.
# 1107 bf_mcmc_scatter_random.csv not found.
# 1108 bf_mcmc_scatter_random.csv not found.
# 1109 bf_mcmc_scatter_random.csv not found.
# 1110 bf_mcmc_scatter_random.csv not found.
# 1111 bf_mcmc_scatter_random.csv not found.
# 1112 bf_mcmc_scatter_random.csv not found.
# 1113 bf_mcmc_scatter_random.csv not found.
# 1114 bf_mcmc_scatter_random.csv not found.
# 1115 bf_mcmc_scatter_random.csv not found.
# 1116 bf_mcmc_scatter_random.csv not found.
# 1117 bf_mcmc_scatter_random.csv not found.
# 1118 bf_mcmc_scatter_random.csv not found.
# 1119 bf_mcmc_scatter_random.csv not found.
# 1120 bf_mcmc_scatter_random.csv not found.
# 1121 bf_mcmc_scatter_random.csv not found.
# 1122 bf_mcmc_scatter_random.csv not found.
# 1123 bf_mcmc_scatter_random.csv not found.
# 1124 bf_mcmc_scatter_random.csv not found.
# 1125 bf_mcmc_scatter_random.csv not found.
# 1126 bf_mcmc_scatter_random.csv not found.
# 1127 bf_mcmc_scatter_random.csv not found.
# 1128 bf_mcmc_scatter_random.csv not found.
# 1129 bf_mcmc_scatter_random.csv not found.
# 1130 bf_mcmc_scatter_random.csv not found.
# 1131 bf_mcmc_scatter_random.csv not found.
# 1132 bf_mcmc_scatter_random.csv not found.
# 1133 bf_mcmc_scatter_random.csv not found.
# 1134 bf_mcmc_scatter_random.csv not found.
# 1135 bf_mcmc_scatter_random.csv not found.
# 1136 bf_mcmc_scatter_random.csv not found.
# 1137 bf_mcmc_scatter_random.csv not found.
# 1138 bf_mcmc_scatter_random.csv not found.
# 1139 bf_mcmc_scatter_random.csv not found.
# 1140 bf_mcmc_scatter_random.csv not found.
# 1141 bf_mcmc_scatter_random.csv not found.
# 1142 bf_mcmc_scatter_random.csv not found.
# 1143 bf_mcmc_scatter_random.csv not found.
# 1144 bf_mcmc_scatter_random.csv not found.
# 1145 bf_mcmc_scatter_random.csv not found.
# 1146 bf_mcmc_scatter_random.csv not found.
# 1147 bf_mcmc_scatter_random.csv not found.
# 1148 bf_mcmc_scatter_random.csv not found.
# 1149 bf_mcmc_scatter_random.csv not found.
# 1150 bf_mcmc_scatter_random.csv not found.
# 1151 bf_mcmc_scatter_random.csv not found.
# 1152 bf_mcmc_scatter_random.csv not found.
# 1153 bf_mcmc_scatter_random.csv not found.
# 1154 bf_mcmc_scatter_random.csv not found.
# 1155 bf_mcmc_scatter_random.csv not found.
# 1156 bf_mcmc_scatter_random.csv not found.
# 1157 bf_mcmc_scatter_random.csv not found.
# 1158 bf_mcmc_scatter_random.csv not found.
# 1159 bf_mcmc_scatter_random.csv not found.
# 1160 bf_mcmc_scatter_random.csv not found.
# 1161 bf_mcmc_scatter_random.csv not found.
# 1162 bf_mcmc_scatter_random.csv not found.
# 1163 bf_mcmc_scatter_random.csv not found.
# 1164 bf_mcmc_scatter_random.csv not found.
# 1165 bf_mcmc_scatter_random.csv not found.
# 1166 bf_mcmc_scatter_random.csv not found.
# 1167 bf_mcmc_scatter_random.csv not found.
# 1168 bf_mcmc_scatter_random.csv not found.
# 1169 bf_mcmc_scatter_random.csv not found.
# 1170 bf_mcmc_scatter_random.csv not found.
# 1171 bf_mcmc_scatter_random.csv not found.
# 1172 bf_mcmc_scatter_random.csv not found.
# 1173 bf_mcmc_scatter_random.csv not found.
# 1174 bf_mcmc_scatter_random.csv not found.
# 1175 bf_mcmc_scatter_random.csv not found.
# 1176 bf_mcmc_scatter_random.csv not found.
# 1177 bf_mcmc_scatter_random.csv not found.
# 1178 bf_mcmc_scatter_random.csv not found.
# 1179 bf_mcmc_scatter_random.csv not found.
# 1180 bf_mcmc_scatter_random.csv not found.
# 1181 bf_mcmc_scatter_random.csv not found.
# 1182 bf_mcmc_scatter_random.csv not found.
# 1183 bf_mcmc_scatter_random.csv not found.
# 1184 bf_mcmc_scatter_random.csv not found.
# 1185 bf_mcmc_scatter_random.csv not found.
# 1186 bf_mcmc_scatter_random.csv not found.
# 1187 bf_mcmc_scatter_random.csv not found.
# 1188 bf_mcmc_scatter_random.csv not found.
# 1189 bf_mcmc_scatter_random.csv not found.
# 1190 bf_mcmc_scatter_random.csv not found.
# 1191 bf_mcmc_scatter_random.csv not found.
# 1192 bf_mcmc_scatter_random.csv not found.
# 1193 bf_mcmc_scatter_random.csv not found.
# 1194 bf_mcmc_scatter_random.csv not found.
# 1195 bf_mcmc_scatter_random.csv not found.
# 1196 bf_mcmc_scatter_random.csv not found.
# 1197 bf_mcmc_scatter_random.csv not found.
# 1198 bf_mcmc_scatter_random.csv not found.
# 1199 bf_mcmc_scatter_random.csv not found.
# 1200 bf_mcmc_scatter_random.csv not found.
# 1201 bf_mcmc_scatter_random.csv not found.
# 1202 bf_mcmc_scatter_random.csv not found.
# 1203 bf_mcmc_scatter_random.csv not found.
# 1204 bf_mcmc_scatter_random.csv not found.
# 1205 bf_mcmc_scatter_random.csv not found.
# 1206 bf_mcmc_scatter_random.csv not found.
# 1207 bf_mcmc_scatter_random.csv not found.
# 1208 bf_mcmc_scatter_random.csv not found.
# 1209 bf_mcmc_scatter_random.csv not found.
# 1210 bf_mcmc_scatter_random.csv not found.
# 1211 bf_mcmc_scatter_random.csv not found.
# 1212 bf_mcmc_scatter_random.csv not found.
# 1213 bf_mcmc_scatter_random.csv not found.
# 1214 bf_mcmc_scatter_random.csv not found.
# 1215 bf_mcmc_scatter_random.csv not found.
# 1216 bf_mcmc_scatter_random.csv not found.
# 1217 bf_mcmc_scatter_random.csv not found.
# 1218 bf_mcmc_scatter_random.csv not found.
# 1219 bf_mcmc_scatter_random.csv not found.
# 1220 bf_mcmc_scatter_random.csv not found.
# 1221 bf_mcmc_scatter_random.csv not found.
# 1222 bf_mcmc_scatter_random.csv not found.
# 1223 bf_mcmc_scatter_random.csv not found.
# 1224 bf_mcmc_scatter_random.csv not found.
# 1225 bf_mcmc_scatter_random.csv not found.
# 1226 bf_mcmc_scatter_random.csv not found.
# 1227 bf_mcmc_scatter_random.csv not found.
# 1228 bf_mcmc_scatter_random.csv not found.
# 1229 bf_mcmc_scatter_random.csv not found.
# 1230 bf_mcmc_scatter_random.csv not found.
# 1231 bf_mcmc_scatter_random.csv not found.
# 1232 bf_mcmc_scatter_random.csv not found.
# 1233 bf_mcmc_scatter_random.csv not found.
# 1234 bf_mcmc_scatter_random.csv not found.
# 1235 bf_mcmc_scatter_random.csv not found.
# 1236 bf_mcmc_scatter_random.csv not found.
# 1237 bf_mcmc_scatter_random.csv not found.
# 1238 bf_mcmc_scatter_random.csv not found.
# 1239 bf_mcmc_scatter_random.csv not found.
# 1240 bf_mcmc_scatter_random.csv not found.
# 1241 bf_mcmc_scatter_random.csv not found.
# 1242 bf_mcmc_scatter_random.csv not found.
# 1243 bf_mcmc_scatter_random.csv not found.
# 1244 bf_mcmc_scatter_random.csv not found.
# 1245 bf_mcmc_scatter_random.csv not found.
# 1246 bf_mcmc_scatter_random.csv not found.
# 1247 bf_mcmc_scatter_random.csv not found.
# 1248 bf_mcmc_scatter_random.csv not found.
# 1249 bf_mcmc_scatter_random.csv not found.
# 1250 bf_mcmc_scatter_random.csv not found.
# 1251 bf_mcmc_scatter_random.csv not found.
# 1252 bf_mcmc_scatter_random.csv not found.
# 1253 bf_mcmc_scatter_random.csv not found.
# 1254 bf_mcmc_scatter_random.csv not found.
# 1255 bf_mcmc_scatter_random.csv not found.
# 1256 bf_mcmc_scatter_random.csv not found.
# 1257 bf_mcmc_scatter_random.csv not found.
# 1258 bf_mcmc_scatter_random.csv not found.
# 1259 bf_mcmc_scatter_random.csv not found.
# 1260 bf_mcmc_scatter_random.csv not found.
# 1261 bf_mcmc_scatter_random.csv not found.
# 1262 bf_mcmc_scatter_random.csv not found.
# 1263 bf_mcmc_scatter_random.csv not found.
# 1264 bf_mcmc_scatter_random.csv not found.
# 1265 bf_mcmc_scatter_random.csv not found.
# 1266 bf_mcmc_scatter_random.csv not found.
# 1267 bf_mcmc_scatter_random.csv not found.
# 1268 bf_mcmc_scatter_random.csv not found.
# 1269 bf_mcmc_scatter_random.csv not found.
# 1270 bf_mcmc_scatter_random.csv not found.
# 1271 bf_mcmc_scatter_random.csv not found.
# 1272 bf_mcmc_scatter_random.csv not found.
# 1273 bf_mcmc_scatter_random.csv not found.
# 1274 bf_mcmc_scatter_random.csv not found.
# 1275 bf_mcmc_scatter_random.csv not found.
# 1276 bf_mcmc_scatter_random.csv not found.
# 1277 bf_mcmc_scatter_random.csv not found.
# 1278 bf_mcmc_scatter_random.csv not found.
# 1279 bf_mcmc_scatter_random.csv not found.
# 1280 bf_mcmc_scatter_random.csv not found.
# 1281 bf_mcmc_scatter_random.csv not found.
# 1282 bf_mcmc_scatter_random.csv not found.
# 1283 bf_mcmc_scatter_random.csv not found.
# 1284 bf_mcmc_scatter_random.csv not found.
# 1285 bf_mcmc_scatter_random.csv not found.
# 1286 bf_mcmc_scatter_random.csv not found.
# 1287 bf_mcmc_scatter_random.csv not found.
# 1288 bf_mcmc_scatter_random.csv not found.
# 1289 bf_mcmc_scatter_random.csv not found.
# 1290 bf_mcmc_scatter_random.csv not found.
# 1291 bf_mcmc_scatter_random.csv not found.
# 1292 bf_mcmc_scatter_random.csv not found.
# 1293 bf_mcmc_scatter_random.csv not found.
# 1294 bf_mcmc_scatter_random.csv not found.
# 1295 bf_mcmc_scatter_random.csv not found.
# 1296 bf_mcmc_scatter_random.csv not found.
# 1297 bf_mcmc_scatter_random.csv not found.
# 1298 bf_mcmc_scatter_random.csv not found.
# 1299 bf_mcmc_scatter_random.csv not found.
# 1300 bf_mcmc_scatter_random.csv not found.
# 1301 bf_mcmc_scatter_random.csv not found.
# 1302 bf_mcmc_scatter_random.csv not found.
# 1303 bf_mcmc_scatter_random.csv not found.
# 1304 bf_mcmc_scatter_random.csv not found.
# 1305 bf_mcmc_scatter_random.csv not found.
# 1306 bf_mcmc_scatter_random.csv not found.
# 1307 bf_mcmc_scatter_random.csv not found.
# 1308 bf_mcmc_scatter_random.csv not found.
# 1309 bf_mcmc_scatter_random.csv not found.
# 1310 bf_mcmc_scatter_random.csv not found.
# 1311 bf_mcmc_scatter_random.csv not found.
# 1312 bf_mcmc_scatter_random.csv not found.
# 1313 bf_mcmc_scatter_random.csv not found.
# 1314 bf_mcmc_scatter_random.csv not found.
# 1315 bf_mcmc_scatter_random.csv not found.
# 1316 bf_mcmc_scatter_random.csv not found.
# 1317 bf_mcmc_scatter_random.csv not found.
# 1318 bf_mcmc_scatter_random.csv not found.
# 1319 bf_mcmc_scatter_random.csv not found.
# 1320 bf_mcmc_scatter_random.csv not found.
# 1321 bf_mcmc_scatter_random.csv not found.
# 1322 bf_mcmc_scatter_random.csv not found.
# 1323 bf_mcmc_scatter_random.csv not found.
# 1324 bf_mcmc_scatter_random.csv not found.
# 1325 bf_mcmc_scatter_random.csv not found.
# 1326 bf_mcmc_scatter_random.csv not found.
# 1327 bf_mcmc_scatter_random.csv not found.
# 1328 bf_mcmc_scatter_random.csv not found.
# 1329 bf_mcmc_scatter_random.csv not found.
# 1330 bf_mcmc_scatter_random.csv not found.
# 1331 bf_mcmc_scatter_random.csv not found.
# 1332 bf_mcmc_scatter_random.csv not found.
# 1333 bf_mcmc_scatter_random.csv not found.
# 1334 bf_mcmc_scatter_random.csv not found.
# 1335 bf_mcmc_scatter_random.csv not found.
# 1336 bf_mcmc_scatter_random.csv not found.
# 1337 bf_mcmc_scatter_random.csv not found.
# 1338 bf_mcmc_scatter_random.csv not found.
# 1339 bf_mcmc_scatter_random.csv not found.
# 1340 bf_mcmc_scatter_random.csv not found.
# 1341 bf_mcmc_scatter_random.csv not found.
# 1342 bf_mcmc_scatter_random.csv not found.
# 1343 bf_mcmc_scatter_random.csv not found.
# 1344 bf_mcmc_scatter_random.csv not found.
# 1345 bf_mcmc_scatter_random.csv not found.
# 1346 bf_mcmc_scatter_random.csv not found.
# 1347 bf_mcmc_scatter_random.csv not found.
# 1348 bf_mcmc_scatter_random.csv not found.
# 1349 bf_mcmc_scatter_random.csv not found.
# 1350 bf_mcmc_scatter_random.csv not found.
# 1351 bf_mcmc_scatter_random.csv not found.
# 1352 bf_mcmc_scatter_random.csv not found.
# 1353 bf_mcmc_scatter_random.csv not found.
# 1354 bf_mcmc_scatter_random.csv not found.
# 1355 bf_mcmc_scatter_random.csv not found.
# 1356 bf_mcmc_scatter_random.csv not found.
# 1357 bf_mcmc_scatter_random.csv not found.
# 1358 bf_mcmc_scatter_random.csv not found.
# 1359 bf_mcmc_scatter_random.csv not found.
# 1360 bf_mcmc_scatter_random.csv not found.
# 1361 bf_mcmc_scatter_random.csv not found.
# 1362 bf_mcmc_scatter_random.csv not found.
# 1363 bf_mcmc_scatter_random.csv not found.
# 1364 bf_mcmc_scatter_random.csv not found.
# 1365 bf_mcmc_scatter_random.csv not found.
# 1366 bf_mcmc_scatter_random.csv not found.
# 1367 bf_mcmc_scatter_random.csv not found.
# 1368 bf_mcmc_scatter_random.csv not found.
# 1369 bf_mcmc_scatter_random.csv not found.
# 1370 bf_mcmc_scatter_random.csv not found.
# 1371 bf_mcmc_scatter_random.csv not found.
# 1372 bf_mcmc_scatter_random.csv not found.
# 1373 bf_mcmc_scatter_random.csv not found.
# 1374 bf_mcmc_scatter_random.csv not found.
# 1375 bf_mcmc_scatter_random.csv not found.
# 1376 bf_mcmc_scatter_random.csv not found.
# 1377 bf_mcmc_scatter_random.csv not found.
# 1378 bf_mcmc_scatter_random.csv not found.
# 1379 bf_mcmc_scatter_random.csv not found.
# 1380 bf_mcmc_scatter_random.csv not found.
# 1381 bf_mcmc_scatter_random.csv not found.
# 1382 bf_mcmc_scatter_random.csv not found.
# 1383 bf_mcmc_scatter_random.csv not found.
# 1384 bf_mcmc_scatter_random.csv not found.
# 1385 bf_mcmc_scatter_random.csv not found.
# 1386 bf_mcmc_scatter_random.csv not found.
# 1387 bf_mcmc_scatter_random.csv not found.
# 1388 bf_mcmc_scatter_random.csv not found.
# 1389 bf_mcmc_scatter_random.csv not found.
# 1390 bf_mcmc_scatter_random.csv not found.
# 1391 bf_mcmc_scatter_random.csv not found.
# 1392 bf_mcmc_scatter_random.csv not found.
# 1393 bf_mcmc_scatter_random.csv not found.
# 1394 bf_mcmc_scatter_random.csv not found.
# 1395 bf_mcmc_scatter_random.csv not found.
# 1396 bf_mcmc_scatter_random.csv not found.
# 1397 bf_mcmc_scatter_random.csv not found.
# 1398 bf_mcmc_scatter_random.csv not found.
# 1399 bf_mcmc_scatter_random.csv not found.
# 1400 bf_mcmc_scatter_random.csv not found.
# 1401 bf_mcmc_scatter_random.csv not found.
# 1402 bf_mcmc_scatter_random.csv not found.
# 1403 bf_mcmc_scatter_random.csv not found.
# 1404 bf_mcmc_scatter_random.csv not found.
# 1405 bf_mcmc_scatter_random.csv not found.
# 1406 bf_mcmc_scatter_random.csv not found.
# 1407 bf_mcmc_scatter_random.csv not found.
# 1408 bf_mcmc_scatter_random.csv not found.
# 1409 bf_mcmc_scatter_random.csv not found.
# 1410 bf_mcmc_scatter_random.csv not found.
# 1411 bf_mcmc_scatter_random.csv not found.
# 1412 bf_mcmc_scatter_random.csv not found.
# 1413 bf_mcmc_scatter_random.csv not found.
# 1414 bf_mcmc_scatter_random.csv not found.
# 1415 bf_mcmc_scatter_random.csv not found.
# 1416 bf_mcmc_scatter_random.csv not found.
# 1417 bf_mcmc_scatter_random.csv not found.
# 1418 bf_mcmc_scatter_random.csv not found.
# 1419 bf_mcmc_scatter_random.csv not found.
# 1420 bf_mcmc_scatter_random.csv not found.
# 1421 bf_mcmc_scatter_random.csv not found.
# 1422 bf_mcmc_scatter_random.csv not found.
# 1423 bf_mcmc_scatter_random.csv not found.
# 1424 bf_mcmc_scatter_random.csv not found.
# 1425 bf_mcmc_scatter_random.csv not found.
# 1426 bf_mcmc_scatter_random.csv not found.
# 1427 bf_mcmc_scatter_random.csv not found.
# 1428 bf_mcmc_scatter_random.csv not found.
# 1429 bf_mcmc_scatter_random.csv not found.
# 1430 bf_mcmc_scatter_random.csv not found.
# 1431 bf_mcmc_scatter_random.csv not found.
# 1432 bf_mcmc_scatter_random.csv not found.
# 1433 bf_mcmc_scatter_random.csv not found.
# 1434 bf_mcmc_scatter_random.csv not found.
# 1435 bf_mcmc_scatter_random.csv not found.
# 1436 bf_mcmc_scatter_random.csv not found.
# 1437 bf_mcmc_scatter_random.csv not found.
# 1438 bf_mcmc_scatter_random.csv not found.
# 1439 bf_mcmc_scatter_random.csv not found.
# 1440 bf_mcmc_scatter_random.csv not found.
# 1441 bf_mcmc_scatter_random.csv not found.
# 1442 bf_mcmc_scatter_random.csv not found.
# 1443 bf_mcmc_scatter_random.csv not found.
# 1444 bf_mcmc_scatter_random.csv not found.
# 1445 bf_mcmc_scatter_random.csv not found.
# 1446 bf_mcmc_scatter_random.csv not found.
# 1447 bf_mcmc_scatter_random.csv not found.
# 1448 bf_mcmc_scatter_random.csv not found.
# 1449 bf_mcmc_scatter_random.csv not found.
# 1450 bf_mcmc_scatter_random.csv not found.
# 1451 bf_mcmc_scatter_random.csv not found.
# 1452 bf_mcmc_scatter_random.csv not found.
# 1453 bf_mcmc_scatter_random.csv not found.
# 1454 bf_mcmc_scatter_random.csv not found.
# 1455 bf_mcmc_scatter_random.csv not found.
# 1456 bf_mcmc_scatter_random.csv not found.
# 1457 bf_mcmc_scatter_random.csv not found.
# 1458 bf_mcmc_scatter_random.csv not found.
# 1459 bf_mcmc_scatter_random.csv not found.
# 1460 bf_mcmc_scatter_random.csv not found.
# 1461 bf_mcmc_scatter_random.csv not found.
# 1462 bf_mcmc_scatter_random.csv not found.
# 1463 bf_mcmc_scatter_random.csv not found.
# 1464 bf_mcmc_scatter_random.csv not found.
# 1465 bf_mcmc_scatter_random.csv not found.
# 1466 bf_mcmc_scatter_random.csv not found.
# 1467 bf_mcmc_scatter_random.csv not found.
# 1468 bf_mcmc_scatter_random.csv not found.
# 1469 bf_mcmc_scatter_random.csv not found.
# 1470 bf_mcmc_scatter_random.csv not found.
# 1471 bf_mcmc_scatter_random.csv not found.
# 1472 bf_mcmc_scatter_random.csv not found.
# 1473 bf_mcmc_scatter_random.csv not found.
# 1474 bf_mcmc_scatter_random.csv not found.
# 1475 bf_mcmc_scatter_random.csv not found.
# 1476 bf_mcmc_scatter_random.csv not found.
# 1477 bf_mcmc_scatter_random.csv not found.
# 1478 bf_mcmc_scatter_random.csv not found.
# 1479 bf_mcmc_scatter_random.csv not found.
# 1480 bf_mcmc_scatter_random.csv not found.
# 1481 bf_mcmc_scatter_random.csv not found.
# 1482 bf_mcmc_scatter_random.csv not found.
# 1483 bf_mcmc_scatter_random.csv not found.
# 1484 bf_mcmc_scatter_random.csv not found.
# 1485 bf_mcmc_scatter_random.csv not found.
# 1486 bf_mcmc_scatter_random.csv not found.
# 1487 bf_mcmc_scatter_random.csv not found.
# 1488 bf_mcmc_scatter_random.csv not found.
# 1489 bf_mcmc_scatter_random.csv not found.
# 1490 bf_mcmc_scatter_random.csv not found.
# 1491 bf_mcmc_scatter_random.csv not found.
# 1492 bf_mcmc_scatter_random.csv not found.
# 1493 bf_mcmc_scatter_random.csv not found.
# 1494 bf_mcmc_scatter_random.csv not found.
# 1495 bf_mcmc_scatter_random.csv not found.
# 1496 bf_mcmc_scatter_random.csv not found.
# 1497 bf_mcmc_scatter_random.csv not found.
# 1498 bf_mcmc_scatter_random.csv not found.
# 1499 bf_mcmc_scatter_random.csv not found.
# 1500 bf_mcmc_scatter_random.csv not found.
# 1501 bf_mcmc_scatter_random.csv not found.
# 1502 bf_mcmc_scatter_random.csv not found.
# 1503 bf_mcmc_scatter_random.csv not found.
# 1504 bf_mcmc_scatter_random.csv not found.
# 1505 bf_mcmc_scatter_random.csv not found.
# 1506 bf_mcmc_scatter_random.csv not found.
# 1507 bf_mcmc_scatter_random.csv not found.
# 1508 bf_mcmc_scatter_random.csv not found.
# 1509 bf_mcmc_scatter_random.csv not found.
# 1510 bf_mcmc_scatter_random.csv not found.
# 1511 bf_mcmc_scatter_random.csv not found.
# 1512 bf_mcmc_scatter_random.csv not found.
# 1513 bf_mcmc_scatter_random.csv not found.
# 1514 bf_mcmc_scatter_random.csv not found.
# 1515 bf_mcmc_scatter_random.csv not found.
# 1516 bf_mcmc_scatter_random.csv not found.
# 1517 bf_mcmc_scatter_random.csv not found.
# 1518 bf_mcmc_scatter_random.csv not found.
# 1519 bf_mcmc_scatter_random.csv not found.
# 1520 bf_mcmc_scatter_random.csv not found.
# 1521 bf_mcmc_scatter_random.csv not found.
# 1522 bf_mcmc_scatter_random.csv not found.
# 1523 bf_mcmc_scatter_random.csv not found.
# 1524 bf_mcmc_scatter_random.csv not found.
# 1525 bf_mcmc_scatter_random.csv not found.
# 1526 bf_mcmc_scatter_random.csv not found.
# 1527 bf_mcmc_scatter_random.csv not found.
# 1528 bf_mcmc_scatter_random.csv not found.
# 1529 bf_mcmc_scatter_random.csv not found.
# 1530 bf_mcmc_scatter_random.csv not found.
# 1531 bf_mcmc_scatter_random.csv not found.
# 1532 bf_mcmc_scatter_random.csv not found.
# 1533 bf_mcmc_scatter_random.csv not found.
# 1534 bf_mcmc_scatter_random.csv not found.
# 1535 bf_mcmc_scatter_random.csv not found.
# 1536 bf_mcmc_scatter_random.csv not found.
# 1537 bf_mcmc_scatter_random.csv not found.
# 1538 bf_mcmc_scatter_random.csv not found.
# 1539 bf_mcmc_scatter_random.csv not found.
# 1540 bf_mcmc_scatter_random.csv not found.
# 1541 bf_mcmc_scatter_random.csv not found.
# 1542 bf_mcmc_scatter_random.csv not found.
# 1543 bf_mcmc_scatter_random.csv not found.
# 1544 bf_mcmc_scatter_random.csv not found.
# 1545 bf_mcmc_scatter_random.csv not found.
# 1546 bf_mcmc_scatter_random.csv not found.
# 1547 bf_mcmc_scatter_random.csv not found.
# 1548 bf_mcmc_scatter_random.csv not found.
# 1549 bf_mcmc_scatter_random.csv not found.
# 1550 bf_mcmc_scatter_random.csv not found.
# 1551 bf_mcmc_scatter_random.csv not found.
# 1552 bf_mcmc_scatter_random.csv not found.
# 1553 bf_mcmc_scatter_random.csv not found.
# 1554 bf_mcmc_scatter_random.csv not found.
# 1555 bf_mcmc_scatter_random.csv not found.
# 1556 bf_mcmc_scatter_random.csv not found.
# 1557 bf_mcmc_scatter_random.csv not found.
# 1558 bf_mcmc_scatter_random.csv not found.
# 1559 bf_mcmc_scatter_random.csv not found.
# 1560 bf_mcmc_scatter_random.csv not found.
# 1561 bf_mcmc_scatter_random.csv not found.
# 1562 bf_mcmc_scatter_random.csv not found.
# 1563 bf_mcmc_scatter_random.csv not found.
# 1564 bf_mcmc_scatter_random.csv not found.
# 1565 bf_mcmc_scatter_random.csv not found.
# 1566 bf_mcmc_scatter_random.csv not found.
# 1567 bf_mcmc_scatter_random.csv not found.
# 1568 bf_mcmc_scatter_random.csv not found.
# 1569 bf_mcmc_scatter_random.csv not found.
# 1570 bf_mcmc_scatter_random.csv not found.
# 1571 bf_mcmc_scatter_random.csv not found.
# 1572 bf_mcmc_scatter_random.csv not found.
# 1573 bf_mcmc_scatter_random.csv not found.
# 1574 bf_mcmc_scatter_random.csv not found.
# 1575 bf_mcmc_scatter_random.csv not found.
# 1576 bf_mcmc_scatter_random.csv not found.
# 1577 bf_mcmc_scatter_random.csv not found.
# 1578 bf_mcmc_scatter_random.csv not found.
# 1579 bf_mcmc_scatter_random.csv not found.
# 1580 bf_mcmc_scatter_random.csv not found.
# 1581 bf_mcmc_scatter_random.csv not found.
# 1582 bf_mcmc_scatter_random.csv not found.
# 1583 bf_mcmc_scatter_random.csv not found.
# 1584 bf_mcmc_scatter_random.csv not found.
# 1585 bf_mcmc_scatter_random.csv not found.
# 1586 bf_mcmc_scatter_random.csv not found.
# 1587 bf_mcmc_scatter_random.csv not found.
# 1588 bf_mcmc_scatter_random.csv not found.
# 1589 bf_mcmc_scatter_random.csv not found.
# 1590 bf_mcmc_scatter_random.csv not found.
# 1591 bf_mcmc_scatter_random.csv not found.
# 1592 bf_mcmc_scatter_random.csv not found.
# 1593 bf_mcmc_scatter_random.csv not found.
# 1594 bf_mcmc_scatter_random.csv not found.
# 1595 bf_mcmc_scatter_random.csv not found.
# 1596 bf_mcmc_scatter_random.csv not found.
# 1597 bf_mcmc_scatter_random.csv not found.
# 1598 bf_mcmc_scatter_random.csv not found.
# 1599 bf_mcmc_scatter_random.csv not found.
# 1600 bf_mcmc_scatter_random.csv not found.
# 1601 bf_mcmc_scatter_random.csv not found.
# 1602 bf_mcmc_scatter_random.csv not found.
# 1603 bf_mcmc_scatter_random.csv not found.
# 1604 bf_mcmc_scatter_random.csv not found.
# 1605 bf_mcmc_scatter_random.csv not found.
# 1606 bf_mcmc_scatter_random.csv not found.
# 1607 bf_mcmc_scatter_random.csv not found.
# 1608 bf_mcmc_scatter_random.csv not found.
# 1609 bf_mcmc_scatter_random.csv not found.
# 1610 bf_mcmc_scatter_random.csv not found.
# 1611 bf_mcmc_scatter_random.csv not found.
# 1612 bf_mcmc_scatter_random.csv not found.
# 1613 bf_mcmc_scatter_random.csv not found.
# 1614 bf_mcmc_scatter_random.csv not found.
# 1615 bf_mcmc_scatter_random.csv not found.
# 1616 bf_mcmc_scatter_random.csv not found.
# 1617 bf_mcmc_scatter_random.csv not found.
# 1618 bf_mcmc_scatter_random.csv not found.
# 1619 bf_mcmc_scatter_random.csv not found.
# 1620 bf_mcmc_scatter_random.csv not found.
# 1621 bf_mcmc_scatter_random.csv not found.
# 1622 bf_mcmc_scatter_random.csv not found.
# 1623 bf_mcmc_scatter_random.csv not found.
# 1624 bf_mcmc_scatter_random.csv not found.
# 1625 bf_mcmc_scatter_random.csv not found.
# 1626 bf_mcmc_scatter_random.csv not found.
# 1627 bf_mcmc_scatter_random.csv not found.
# 1628 bf_mcmc_scatter_random.csv not found.
# 1629 bf_mcmc_scatter_random.csv not found.
# 1630 bf_mcmc_scatter_random.csv not found.
# 1631 bf_mcmc_scatter_random.csv not found.
# 1632 bf_mcmc_scatter_random.csv not found.
# 1633 bf_mcmc_scatter_random.csv not found.
# 1634 bf_mcmc_scatter_random.csv not found.
# 1635 bf_mcmc_scatter_random.csv not found.
# 1636 bf_mcmc_scatter_random.csv not found.
# 1637 bf_mcmc_scatter_random.csv not found.
# 1638 bf_mcmc_scatter_random.csv not found.
# 1639 bf_mcmc_scatter_random.csv not found.
# 1640 bf_mcmc_scatter_random.csv not found.
# 1641 bf_mcmc_scatter_random.csv not found.
# 1642 bf_mcmc_scatter_random.csv not found.
# 1643 bf_mcmc_scatter_random.csv not found.
# 1644 bf_mcmc_scatter_random.csv not found.
# 1645 bf_mcmc_scatter_random.csv not found.
# 1646 bf_mcmc_scatter_random.csv not found.
# 1647 bf_mcmc_scatter_random.csv not found.
# 1648 bf_mcmc_scatter_random.csv not found.
# 1649 bf_mcmc_scatter_random.csv not found.
# 1650 bf_mcmc_scatter_random.csv not found.
# 1651 bf_mcmc_scatter_random.csv not found.
# 1652 bf_mcmc_scatter_random.csv not found.
# 1653 bf_mcmc_scatter_random.csv not found.
# 1654 bf_mcmc_scatter_random.csv not found.
# 1655 bf_mcmc_scatter_random.csv not found.
# 1656 bf_mcmc_scatter_random.csv not found.
# 1657 bf_mcmc_scatter_random.csv not found.
# 1658 bf_mcmc_scatter_random.csv not found.
# 1659 bf_mcmc_scatter_random.csv not found.
# 1660 bf_mcmc_scatter_random.csv not found.
# 1661 bf_mcmc_scatter_random.csv not found.
# 1662 bf_mcmc_scatter_random.csv not found.
# 1663 bf_mcmc_scatter_random.csv not found.
# 1664 bf_mcmc_scatter_random.csv not found.
# 1665 bf_mcmc_scatter_random.csv not found.
# 1666 bf_mcmc_scatter_random.csv not found.
# 1667 bf_mcmc_scatter_random.csv not found.
# 1668 bf_mcmc_scatter_random.csv not found.
# 1669 bf_mcmc_scatter_random.csv not found.
# 1670 bf_mcmc_scatter_random.csv not found.
# 1671 bf_mcmc_scatter_random.csv not found.
# 1672 bf_mcmc_scatter_random.csv not found.
# 1673 bf_mcmc_scatter_random.csv not found.
# 1674 bf_mcmc_scatter_random.csv not found.
# 1675 bf_mcmc_scatter_random.csv not found.
# 1676 bf_mcmc_scatter_random.csv not found.
# 1677 bf_mcmc_scatter_random.csv not found.
# 1678 bf_mcmc_scatter_random.csv not found.
# 1679 bf_mcmc_scatter_random.csv not found.
# 1680 bf_mcmc_scatter_random.csv not found.
# 1681 bf_mcmc_scatter_random.csv not found.
# 1682 bf_mcmc_scatter_random.csv not found.
# 1683 bf_mcmc_scatter_random.csv not found.
# 1684 bf_mcmc_scatter_random.csv not found.
# 1685 bf_mcmc_scatter_random.csv not found.
# 1686 bf_mcmc_scatter_random.csv not found.
# 1687 bf_mcmc_scatter_random.csv not found.
# 1688 bf_mcmc_scatter_random.csv not found.
# 1689 bf_mcmc_scatter_random.csv not found.
# 1690 bf_mcmc_scatter_random.csv not found.
# 1691 bf_mcmc_scatter_random.csv not found.
# 1692 bf_mcmc_scatter_random.csv not found.
# 1693 bf_mcmc_scatter_random.csv not found.
# 1694 bf_mcmc_scatter_random.csv not found.
# 1695 bf_mcmc_scatter_random.csv not found.
# 1696 bf_mcmc_scatter_random.csv not found.
# 1697 bf_mcmc_scatter_random.csv not found.
# 1698 bf_mcmc_scatter_random.csv not found.
# 1699 bf_mcmc_scatter_random.csv not found.
# 1700 bf_mcmc_scatter_random.csv not found.
# 1701 bf_mcmc_scatter_random.csv not found.
# 1702 bf_mcmc_scatter_random.csv not found.
# 1703 bf_mcmc_scatter_random.csv not found.
# 1704 bf_mcmc_scatter_random.csv not found.
# 1705 bf_mcmc_scatter_random.csv not found.
# 1706 bf_mcmc_scatter_random.csv not found.
# 1707 bf_mcmc_scatter_random.csv not found.
# 1708 bf_mcmc_scatter_random.csv not found.
# 1709 bf_mcmc_scatter_random.csv not found.
# 1710 bf_mcmc_scatter_random.csv not found.
# 1711 bf_mcmc_scatter_random.csv not found.
# 1712 bf_mcmc_scatter_random.csv not found.
# 1713 bf_mcmc_scatter_random.csv not found.
# 1714 bf_mcmc_scatter_random.csv not found.
# 1715 bf_mcmc_scatter_random.csv not found.
# 1716 bf_mcmc_scatter_random.csv not found.
# 1717 bf_mcmc_scatter_random.csv not found.
# 1718 bf_mcmc_scatter_random.csv not found.
# 1719 bf_mcmc_scatter_random.csv not found.
# 1720 bf_mcmc_scatter_random.csv not found.
# 1721 bf_mcmc_scatter_random.csv not found.
# 1722 bf_mcmc_scatter_random.csv not found.
# 1723 bf_mcmc_scatter_random.csv not found.
# 1724 bf_mcmc_scatter_random.csv not found.
# 1725 bf_mcmc_scatter_random.csv not found.
# 1726 bf_mcmc_scatter_random.csv not found.
# 1727 bf_mcmc_scatter_random.csv not found.
#      scaling_relation  zmax         ubf  ubf_err_lower  ubf_err_upper  \
# 0                LX-T  0.07  332.487719     224.425568     295.033483
# 1                LX-T  0.10  330.858281     229.473937     292.296590
# 2                LX-T  0.13  339.893582     232.678041     306.465765
# 3               YSZ-T  0.07  215.499422     151.809793     227.792821
# 4               YSZ-T  0.10  219.066925     152.861120     224.248570
# ...               ...   ...         ...            ...            ...
# 2703            YSZ-T  0.07  395.913645     256.292373     312.775720
# 2704            YSZ-T  0.10  406.734516     270.955141     304.385815
# 2705            YSZ-T  0.13  396.400181     263.068356     305.741797
# 2706             LX-T  0.07  496.613915     228.767004     245.499737
# 2707             LX-T  0.10  494.958529     223.938887     232.876381
#
#             vlon  vlon_err_lower  vlon_err_upper       vlat  vlat_err_lower  \
# 0      96.016530       99.972249       42.118687   4.058761       39.604139
# 1      83.939350      213.452148       41.689413   3.967734       39.305693
# 2      95.962121      110.114438       40.113636   3.785941       37.766722
# 3     -83.915219       66.074182       84.894702  -2.666787       44.742008
# 4    -107.944129      122.879819       60.962794  -2.613529       43.653980
# ...          ...             ...             ...        ...             ...
# 2703   47.957161       62.879367       47.382285 -28.118968       34.102767
# 2704   36.157597      169.880919       40.152988 -28.058536       32.243343
# 2705   48.005670       64.335636       45.748329 -27.697914       33.085098
# 2706  155.986112       74.548819       49.094101 -58.095677       20.249152
# 2707  155.961887       71.326523       50.099759 -58.563527       19.751434
#
#       vlat_err_upper  convergence_time  Lightcone
# 0          34.732228        121.880082          0
# 1          33.828528        123.215641          0
# 2          33.389070        114.103850          0
# 3          50.523946         99.316776          0
# 4          51.071062         96.565315          0
# ...              ...               ...        ...
# 2703       32.261118         91.542335        826
# 2704       32.690708         93.702048        826
# 2705       33.103487         96.357440        826
# 2706       20.082433        168.125030        827
# 2707       20.420658          0.000000        827
#
# [2708 rows x 13 columns]

# %%
data.to_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# %%
print(len(data)/6)
# Out:
# 451.3333333333333

# %% [markdown]
# ## Load functions

# %%
# !ls /cosma/home/do012/dc-he4/anisotropy-flamingo/data/analysis_all/
# Out:
# bf_mc_all.csv			  h0_mc_all.csv
# bf_mc_all_scatter.csv		  h0_mc_all_full.csv
# bf_mc_random.csv		  h0_mc_joint_all.csv
# bf_mc_scatter_random.csv	  h0_mc_joint_scatter_all.csv
# bf_mc_zcos.csv			  h0_mc_joint_scatter_random.csv
# bf_truth.csv			  h0_mcmc_random.csv
# concatenated_fit_all.csv	  h0_mc_scatter.csv
# concatenated_fit_all_mc.csv	  h0_mc_scatter_random.csv
# concatenated_fit_all_scatter.csv  h0_mc_zcos.csv
# h0_angle_constraint_mc.csv	  scatter_LX-T_added_scatter.csv
# h0_angle_constraint_scan.csv	  scatter_LX-T.csv
# h0_angle_constraints.csv	  scatter_M-T.csv
# h0_direct_compare.csv		  scatter_YSZ-T_added_scatter.csv
# h0_direct_compare_scatter.csv	  scatter_YSZ-T.csv

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from scipy.stats import genpareto
from scipy.special import erfinv
import math
import matplotlib.pyplot as plt
import clusterfit as cf
import clusterplot as cp
plt.style.use('./nice.mplstyle')

# Set percentile for EVS threshold
percentile = 95

def calculate_sigma_p_value(proj, target_value):
    median = np.median(proj)
    sigma_84th = np.percentile(proj, 84)
    sigma = sigma_84th - median
    sigma_deviation = np.abs((target_value - median) / sigma)
    p_value_sigma = 1 - math.erf(sigma_deviation / np.sqrt(2))
    return sigma_deviation, p_value_sigma

# Function to calculate EVT p-value
def calculate_evt_p_value(proj, target_value, percentile):
    # Determine the threshold
    threshold = np.percentile(proj, percentile)
    exceedances = proj[proj > threshold] - threshold  # Tail data

    # Fit GPD to the tail data
    params = genpareto.fit(exceedances)

    # Tail survival probability (proportion of data in the tail)
    tail_prob = np.sum(proj >= threshold) / len(proj)

    if target_value > threshold:
        # Conditional probability adjusted to match at the threshold
        p_value_evt = (1 - genpareto.cdf(target_value - threshold, *params)) * tail_prob
    else:
        # Empirical CDF for the bulk region
        p_value_evt = np.sum(proj >= target_value) / len(proj)

    # Transform to sigma (Gaussian equivalent deviation)
    sigma_evt = np.sqrt(2) * erfinv(1 - p_value_evt)

    return p_value_evt, sigma_evt


# The first projection function
def default_proj(y, n_sigma):
    return y - y / n_sigma

# %%
def __calc_and_plot():
    """ Interior function to avoid copy pasting the same procedure 100 times."""

    # Number of sigma deviation
    sigma_deviation, p_value_sigma = calculate_sigma_p_value(x, target_value)
    print(f"Number of std deviation: p={p_value_sigma:.3g}\\,({sigma_deviation:.3g}\\sigma)")

    # Calculate EVT p-value and sigma deviation
    p_value_evt, sigma_evt = calculate_evt_p_value(x, target_value, percentile=percentile)
    print(f"EVT p-value: p={p_value_evt:.3g}\\,({sigma_evt:.3g}\\sigma)")

    # Plotting results
    fig = plt.figure(figsize=(5, 3))
    plt.hist(x, bins=30, density=True, alpha=0.6, color='#7570b3', label='FLAMINGO')

    # Fit a GPD distribution
    threshold = np.percentile(x, percentile)
    exceedances = x[x > threshold] - threshold
    params = genpareto.fit(exceedances)
    shape, loc, scale = params

    # Plot fitted distribution
    x_vals = np.linspace(threshold, x.max(), 100)
    gpd_pdf = genpareto.pdf(x_vals - threshold, shape, loc, scale) * (1 - percentile / 100)
    plt.axvline(target_value, color='red', linestyle='-', label='Migkas+21')
    plt.plot(x_vals[1:], gpd_pdf[1:], color='g', label='Fitted GPD (Tail)')
    plt.axvline(threshold, color='blue', linestyle='--', label='Threshold (90th Percentile)')

    # Annotate the plot
    plt.annotate(f'p={p_value_evt:.2g}', 
                xy=(target_value, 0.002), xycoords='data',
                xytext=(target_value - 100, 0.002), textcoords='data',
                arrowprops=dict(arrowstyle='->,head_width=.15', color='red'),
                horizontalalignment='right', verticalalignment='center', color='red')

    plt.xlabel('$x$')
    plt.ylabel('Density')
    plt.legend(fontsize=9)

    return fig
    
def __calc_and_plot_small():
    """ Interior function to avoid copy pasting the same procedure 100 times."""

    # Number of sigma deviation
    sigma_deviation, p_value_sigma = calculate_sigma_p_value(x, target_value)
    print(f"Number of std deviation: p={p_value_sigma:.3g}\\,({sigma_deviation:.3g}\\sigma)")

    # Calculate EVT p-value and sigma deviation
    p_value_evt, sigma_evt = calculate_evt_p_value(x, target_value, percentile=percentile)
    print(f"EVT p-value: p={p_value_evt:.3g}\\,({sigma_evt:.3g}\\sigma)")

    # Fit a GPD distribution
    threshold = np.percentile(x, percentile)
    exceedances = x[x > threshold] - threshold
    params = genpareto.fit(exceedances)
    shape, loc, scale = params

    # Fitted distribution
    x_vals = np.linspace(threshold, x.max(), 100)
    gpd_pdf = genpareto.pdf(x_vals - threshold, shape, loc, scale) * (1 - percentile / 100)

    # Plot
    fig, ax = cp._small_evs_(distribution=x,
                            target_value=target_value,
                            x_vals=x_vals,
                            gpd_pdf=gpd_pdf,
                            threshold=threshold,
                            percentile=percentile,
                            sigma_evt=sigma_evt, color='#7570b3')

    return fig

# %% [markdown]
# ## Lx-T
# z = 0.07, 0.10

# %%
# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.07
zmask = data['zmax'] == 0.07
seg = data[zmask][data['scaling_relation'] == 'LX-T'][['ubf', 'ubf_err_lower']]

# Calculate the projection values
x = seg['ubf'].values - seg['ubf_err_lower'].values

# Define the target value
target_value = 1100 - 410
# Out:
# /tmp/ipykernel_2609088/1922611355.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   seg = data[zmask][data['scaling_relation'] == 'LX-T'][['ubf', 'ubf_err_lower']]

# %%
fig = __calc_and_plot_small()
# plt.savefig(f'./to_paper/evs_bulk_flow_L_z0.07.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=0.0225\,(2.28\sigma)
# EVT p-value: p=0.00114\,(3.25\sigma)

# %%
# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.10
zmask = data['zmax'] == 0.10
seg = data[zmask][data['scaling_relation'] == 'LX-T'][['ubf', 'ubf_err_lower']]

# Calculate the projection values
x = seg['ubf'].values - seg['ubf_err_lower'].values

# Define the target value
target_value = 1080 - 380
# Out:
# /tmp/ipykernel_2609088/2745127228.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   seg = data[zmask][data['scaling_relation'] == 'LX-T'][['ubf', 'ubf_err_lower']]

# %%
fig = __calc_and_plot_small()
# plt.savefig(f'./to_paper/evs_bulk_flow_L_z0.10.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=0.0192\,(2.34\sigma)
# EVT p-value: p=0.000195\,(3.73\sigma)

# %% [markdown]
# ## Ysz-T
# z = 0.07, 0.10

# %%
# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.07
zmask = data['zmax'] == 0.07
seg = data[zmask][data['scaling_relation'] == 'YSZ-T'][['ubf', 'ubf_err_lower']]

# Calculate the projection values
x = seg['ubf'].values - seg['ubf_err_lower'].values

# Define the target value
target_value = 1060 - 390
# Out:
# /tmp/ipykernel_2609088/626392434.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   seg = data[zmask][data['scaling_relation'] == 'YSZ-T'][['ubf', 'ubf_err_lower']]

# %%
fig = __calc_and_plot_small()
# plt.savefig(f'./to_paper/evs_bulk_flow_Y_z0.07.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=1.38e-11\,(6.76\sigma)
# EVT p-value: p=0\,(inf\sigma)

# %%
# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.10
zmask = data['zmax'] == 0.10
seg = data[zmask][data['scaling_relation'] == 'YSZ-T'][['ubf', 'ubf_err_lower']]

# Calculate the projection values
x = seg['ubf'].values - seg['ubf_err_lower'].values

# Define the target value
target_value = 1020 - 380
# Out:
# /tmp/ipykernel_2609088/461369549.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   seg = data[zmask][data['scaling_relation'] == 'YSZ-T'][['ubf', 'ubf_err_lower']]

# %%
fig = __calc_and_plot_small()
# plt.savefig(f'./to_paper/evs_bulk_flow_Y_z0.10.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=1.46e-10\,(6.41\sigma)
# EVT p-value: p=0\,(inf\sigma)

# %% [markdown]
# ## Joint of LT, YT

# %%
# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.07
zmask = data['zmax'] == 0.07
uLT = data[zmask][data['scaling_relation'] == 'LX-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]
uYT = data[zmask][data['scaling_relation'] == 'YSZ-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]

# Merge the data on Lightcone
u = pd.merge(left=uLT, right=uYT, on='Lightcone', suffixes=('_LT', '_YT'))

# Calculate the projection values
theta = cf.angular_separation(u['vlon_LT'].values, u['vlat_LT'].values,
    u['vlon_YT'].values, u['vlon_YT'].values) * np.pi/180
x = (u['ubf_LT'].values - u['ubf_err_lower_LT'].values) * np.cos(theta / 2) +\
    (u['ubf_YT'].values - u['ubf_err_lower_YT'].values) * np.cos(theta / 2)
x /= 2

# Define the target value
th = cf.angular_separation(318, -5, 254, -17) * np.pi/180
target_value = (1100 - 410) * np.cos(th / 2) + (1060 - 390) * np.cos(th / 2)
target_value /= 2
# Out:
# /tmp/ipykernel_2609088/3229096291.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   uLT = data[zmask][data['scaling_relation'] == 'LX-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]
# /tmp/ipykernel_2609088/3229096291.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   uYT = data[zmask][data['scaling_relation'] == 'YSZ-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]

# %%
fig = __calc_and_plot()
plt.xlabel(r'$x=|\vec{x}_{LT} + \vec{x}_{YT}|/2$')
# plt.savefig(f'./to_paper/evs_bulk_flow_joint_z0.07.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=1.77e-08\,(5.63\sigma)
# EVT p-value: p=0.000266\,(3.65\sigma)

# %% [markdown]
# ## Joint of LT YT

# %%
import pandas as pd

# Load the data
data = pd.read_csv('../data/analysis_all/bf_mc_scatter_random.csv')

# Filter data for zmax = 0.10
zmask = data['zmax'] == 0.10
uLT = data[zmask][data['scaling_relation'] == 'LX-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]
uYT = data[zmask][data['scaling_relation'] == 'YSZ-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]

# Merge the data on Lightcone
u = pd.merge(left=uLT, right=uYT, on='Lightcone', suffixes=('_LT', '_YT'))

# Calculate the projection values
theta = cf.angular_separation(u['vlon_LT'].values, u['vlat_LT'].values,
    u['vlon_YT'].values, u['vlon_YT'].values) * np.pi/180
x = (u['ubf_LT'].values - u['ubf_err_lower_LT'].values) * np.cos(theta / 2) +\
    (u['ubf_YT'].values - u['ubf_err_lower_YT'].values) * np.cos(theta / 2)
x /= 2

# Define the target value
th = cf.angular_separation(257, -28, 322, -13) * np.pi/180
target_value = (1080-380) * np.cos(th / 2) + (1020-380) * np.cos(th / 2)
target_value /= 2
# Out:
# /tmp/ipykernel_2609088/1439788236.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   uLT = data[zmask][data['scaling_relation'] == 'LX-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]
# /tmp/ipykernel_2609088/1439788236.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   uYT = data[zmask][data['scaling_relation'] == 'YSZ-T'][['Lightcone', 'ubf', 'ubf_err_lower', 'vlat', 'vlon']]

# %%
fig = __calc_and_plot()
plt.xlabel(r'$x=|\vec{x}_{LT} + \vec{x}_{YT}|/2$')
# plt.savefig(f'./to_paper/evs_bulk_flow_joint_z0.10.pdf', bbox_inches='tight')   # save the figure
plt.show()
# Out:
# Number of std deviation: p=9.26e-09\,(5.74\sigma)
# EVT p-value: p=0.000299\,(3.62\sigma)
