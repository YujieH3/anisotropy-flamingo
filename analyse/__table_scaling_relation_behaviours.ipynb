# %% [markdown]
# # Plot the full sky best fit behaviours
# The temperature used is the Chandra temperature. As default by the M21 analysis.

# %%
import os
import pandas as pd
import numpy as np

data_dir = '/cosma8/data/do012/dc-he4/analysis'
all_data = []

for lc in range(1728):
    lc00 = f'{lc:04d}'
    filename = f'{data_dir}/lc{lc00}/fit_all.csv'
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        df['Lightcone'] = lc
        all_data.append(df)

# Concatenate all dataframes
df = pd.concat(all_data, ignore_index=True)

# %%
# Write the concatenated dataframe to a CSV file
output_filename = f'/cosma8/data/do012/dc-he4/analysis_all/concatenated_fit_all.csv'
df.to_csv(output_filename, index=False)

# %% [markdown]
# Read and get data

# %%
import pandas as pd
df = pd.read_csv('/cosma8/data/do012/dc-he4/analysis_all/concatenated_fit_all.csv')
df
# Out:
#      Relation  BestFitA  BestFitB  BestFitScat  1SigmaUpperA  1SigmaLowerA  \
# 0        LX-T  1.737801     2.216        0.161      1.761976      1.698244
# 1       YSZ-T  1.083852     2.406        0.104      1.098930      1.064070
# 2         M-T  1.073915     1.822        0.077      1.083852      1.054314
# 3        LX-T  1.713957     2.168        0.155      1.737801      1.667247
# 4       YSZ-T  1.083852     2.402        0.110      1.098930      1.064070
# ...       ...       ...       ...          ...           ...           ...
# 5183    YSZ-T  1.088855     2.426        0.110      1.114218      1.073915
# 5184      M-T  1.073915     1.842        0.080      1.079769      1.059181
# 5185     LX-T  1.745822     2.220        0.158      1.778279      1.706082
# 5186    YSZ-T  1.088855     2.456        0.116      1.109098      1.073915
# 5187      M-T  1.083852     1.833        0.080      1.088855      1.054314
#
#       1SigmaUpperB  1SigmaLowerB  1SigmaUpperScat  1SigmaLowerScat  Lightcone
# 0            2.264       2.15974            0.167            0.149          0
# 1            2.436       2.37000            0.107            0.098          0
# 2            1.842       1.78400            0.080            0.071          0
# 3            2.228       2.10172            0.161            0.143          1
# 4            2.434       2.36800            0.116            0.104          1
# ...            ...           ...              ...              ...        ...
# 5183         2.462       2.38700            0.116            0.098       1726
# 5184         1.875       1.80600            0.080            0.068       1726
# 5185         2.280       2.16000            0.164            0.140       1727
# 5186         2.492       2.42000            0.116            0.104       1727
# 5187         1.854       1.77900            0.080            0.068       1727
#
# [5188 rows x 11 columns]

# %%
df.drop_duplicates()
# Out:
#      Relation  BestFitA  BestFitB  BestFitScat  1SigmaUpperA  1SigmaLowerA  \
# 0        LX-T  1.737801     2.216        0.161      1.761976      1.698244
# 1       YSZ-T  1.083852     2.406        0.104      1.098930      1.064070
# 2         M-T  1.073915     1.822        0.077      1.083852      1.054314
# 3        LX-T  1.713957     2.168        0.155      1.737801      1.667247
# 4       YSZ-T  1.083852     2.402        0.110      1.098930      1.064070
# ...       ...       ...       ...          ...           ...           ...
# 5183    YSZ-T  1.088855     2.426        0.110      1.114218      1.073915
# 5184      M-T  1.073915     1.842        0.080      1.079769      1.059181
# 5185     LX-T  1.745822     2.220        0.158      1.778279      1.706082
# 5186    YSZ-T  1.088855     2.456        0.116      1.109098      1.073915
# 5187      M-T  1.083852     1.833        0.080      1.088855      1.054314
#
#       1SigmaUpperB  1SigmaLowerB  1SigmaUpperScat  1SigmaLowerScat  Lightcone
# 0            2.264       2.15974            0.167            0.149          0
# 1            2.436       2.37000            0.107            0.098          0
# 2            1.842       1.78400            0.080            0.071          0
# 3            2.228       2.10172            0.161            0.143          1
# 4            2.434       2.36800            0.116            0.104          1
# ...            ...           ...              ...              ...        ...
# 5183         2.462       2.38700            0.116            0.098       1726
# 5184         1.875       1.80600            0.080            0.068       1726
# 5185         2.280       2.16000            0.164            0.140       1727
# 5186         2.492       2.42000            0.116            0.104       1727
# 5187         1.854       1.77900            0.080            0.068       1727
#
# [5188 rows x 11 columns]

# %%
for relation in ['LX-T', 'YSZ-T', 'M-T']:
    mask = df['Relation'] == relation
    masked_df = df[mask]
    print(relation)
    for key in ['BestFitA', 'BestFitB', 'BestFitScat']:
        arr = masked_df[key].values
        median = np.median(arr)
        eightyfourth = np.percentile(arr, 84)
        sixteenth = np.percentile(arr, 16)
        print(f'{key} = {median:.3f} +{eightyfourth - median:.3f} -{median - sixteenth:.3f}')
# Out:
# LX-T
# BestFitA = 1.770 +0.041 -0.032
# BestFitB = 2.220 +0.070 -0.078
# BestFitScat = 0.164 +0.012 -0.009
# YSZ-T
# BestFitA = 1.094 +0.015 -0.020
# BestFitB = 2.441 +0.030 -0.033
# BestFitScat = 0.110 +0.006 -0.006
# M-T
# BestFitA = 1.079 +0.010 -0.010
# BestFitB = 1.827 +0.039 -0.039
# BestFitScat = 0.080 +0.006 -0.006

# %%
# Converted fit
3.6**(1/0.89)
# Out:
# 4.217537857787459
