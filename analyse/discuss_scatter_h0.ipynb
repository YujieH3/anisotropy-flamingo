# %%
import os
import pandas as pd
import numpy as np
data_dir = '/cosma8/data/do012/dc-he4/analysis'

dict = {}
for lc in range(1728):
    lc00 = f'{lc:04d}'

    filename = f'{data_dir}/lc{lc00}/h0_mcmc_scatter.csv'

    # check if file exists
    if os.path.exists(filename):
        df = pd.read_csv(filename)

        # save to df
        if 'delta' not in list(dict.keys()):  # dict.keys() is of type dict_keys
            for key in df.keys():           # load all data
                dict[key] = df[key]

            length = len(df[key])           # register lightcone number
            dict['Lightcone'] = np.full(length, lc)
        else:
            for key in df.keys():           # load all data
                dict[key] = np.concatenate((dict[key], df[key]))

            length = len(df[key])           # register lightcone number
            dict['Lightcone'] = np.concatenate((dict['Lightcone'], np.full(length, lc)))

    else:
        print(lc00, 'h0_mcmc_scatter.csv not found.')
        continue
    
data = pd.DataFrame(dict)

data
# Out:
# 1215 h0_mcmc_scatter.csv not found.
# 1597 h0_mcmc_scatter.csv not found.
# 1598 h0_mcmc_scatter.csv not found.
# 1599 h0_mcmc_scatter.csv not found.
# 1600 h0_mcmc_scatter.csv not found.
# 1601 h0_mcmc_scatter.csv not found.
# 1602 h0_mcmc_scatter.csv not found.
# 1603 h0_mcmc_scatter.csv not found.
# 1604 h0_mcmc_scatter.csv not found.
# 1605 h0_mcmc_scatter.csv not found.
# 1606 h0_mcmc_scatter.csv not found.
# 1607 h0_mcmc_scatter.csv not found.
# 1608 h0_mcmc_scatter.csv not found.
# 1609 h0_mcmc_scatter.csv not found.
# 1610 h0_mcmc_scatter.csv not found.
# 1611 h0_mcmc_scatter.csv not found.
# 1612 h0_mcmc_scatter.csv not found.
# 1613 h0_mcmc_scatter.csv not found.
# 1614 h0_mcmc_scatter.csv not found.
# 1615 h0_mcmc_scatter.csv not found.
# 1616 h0_mcmc_scatter.csv not found.
# 1617 h0_mcmc_scatter.csv not found.
# 1618 h0_mcmc_scatter.csv not found.
# 1619 h0_mcmc_scatter.csv not found.
# 1620 h0_mcmc_scatter.csv not found.
# 1621 h0_mcmc_scatter.csv not found.
# 1622 h0_mcmc_scatter.csv not found.
# 1623 h0_mcmc_scatter.csv not found.
# 1624 h0_mcmc_scatter.csv not found.
# 1625 h0_mcmc_scatter.csv not found.
# 1626 h0_mcmc_scatter.csv not found.
# 1627 h0_mcmc_scatter.csv not found.
# 1628 h0_mcmc_scatter.csv not found.
# 1629 h0_mcmc_scatter.csv not found.
# 1630 h0_mcmc_scatter.csv not found.
# 1631 h0_mcmc_scatter.csv not found.
# 1632 h0_mcmc_scatter.csv not found.
# 1633 h0_mcmc_scatter.csv not found.
# 1634 h0_mcmc_scatter.csv not found.
# 1635 h0_mcmc_scatter.csv not found.
# 1636 h0_mcmc_scatter.csv not found.
# 1637 h0_mcmc_scatter.csv not found.
# 1638 h0_mcmc_scatter.csv not found.
# 1639 h0_mcmc_scatter.csv not found.
# 1640 h0_mcmc_scatter.csv not found.
# 1641 h0_mcmc_scatter.csv not found.
# 1642 h0_mcmc_scatter.csv not found.
# 1643 h0_mcmc_scatter.csv not found.
# 1644 h0_mcmc_scatter.csv not found.
# 1645 h0_mcmc_scatter.csv not found.
# 1646 h0_mcmc_scatter.csv not found.
# 1647 h0_mcmc_scatter.csv not found.
# 1648 h0_mcmc_scatter.csv not found.
# 1649 h0_mcmc_scatter.csv not found.
# 1650 h0_mcmc_scatter.csv not found.
# 1651 h0_mcmc_scatter.csv not found.
# 1652 h0_mcmc_scatter.csv not found.
# 1653 h0_mcmc_scatter.csv not found.
# 1654 h0_mcmc_scatter.csv not found.
# 1655 h0_mcmc_scatter.csv not found.
# 1656 h0_mcmc_scatter.csv not found.
# 1657 h0_mcmc_scatter.csv not found.
# 1658 h0_mcmc_scatter.csv not found.
# 1659 h0_mcmc_scatter.csv not found.
# 1660 h0_mcmc_scatter.csv not found.
# 1661 h0_mcmc_scatter.csv not found.
# 1662 h0_mcmc_scatter.csv not found.
# 1663 h0_mcmc_scatter.csv not found.
# 1664 h0_mcmc_scatter.csv not found.
# 1665 h0_mcmc_scatter.csv not found.
# 1666 h0_mcmc_scatter.csv not found.
# 1667 h0_mcmc_scatter.csv not found.
# 1668 h0_mcmc_scatter.csv not found.
# 1669 h0_mcmc_scatter.csv not found.
# 1670 h0_mcmc_scatter.csv not found.
# 1671 h0_mcmc_scatter.csv not found.
# 1672 h0_mcmc_scatter.csv not found.
# 1673 h0_mcmc_scatter.csv not found.
# 1674 h0_mcmc_scatter.csv not found.
# 1675 h0_mcmc_scatter.csv not found.
# 1676 h0_mcmc_scatter.csv not found.
# 1677 h0_mcmc_scatter.csv not found.
# 1678 h0_mcmc_scatter.csv not found.
# 1679 h0_mcmc_scatter.csv not found.
# 1680 h0_mcmc_scatter.csv not found.
# 1681 h0_mcmc_scatter.csv not found.
# 1682 h0_mcmc_scatter.csv not found.
# 1683 h0_mcmc_scatter.csv not found.
# 1684 h0_mcmc_scatter.csv not found.
# 1685 h0_mcmc_scatter.csv not found.
# 1686 h0_mcmc_scatter.csv not found.
# 1687 h0_mcmc_scatter.csv not found.
# 1688 h0_mcmc_scatter.csv not found.
# 1689 h0_mcmc_scatter.csv not found.
# 1690 h0_mcmc_scatter.csv not found.
# 1691 h0_mcmc_scatter.csv not found.
# 1692 h0_mcmc_scatter.csv not found.
# 1693 h0_mcmc_scatter.csv not found.
# 1694 h0_mcmc_scatter.csv not found.
# 1695 h0_mcmc_scatter.csv not found.
# 1696 h0_mcmc_scatter.csv not found.
# 1697 h0_mcmc_scatter.csv not found.
# 1698 h0_mcmc_scatter.csv not found.
# 1699 h0_mcmc_scatter.csv not found.
# 1700 h0_mcmc_scatter.csv not found.
# 1701 h0_mcmc_scatter.csv not found.
# 1702 h0_mcmc_scatter.csv not found.
# 1703 h0_mcmc_scatter.csv not found.
# 1704 h0_mcmc_scatter.csv not found.
# 1705 h0_mcmc_scatter.csv not found.
# 1706 h0_mcmc_scatter.csv not found.
# 1707 h0_mcmc_scatter.csv not found.
# 1708 h0_mcmc_scatter.csv not found.
# 1709 h0_mcmc_scatter.csv not found.
# 1710 h0_mcmc_scatter.csv not found.
# 1711 h0_mcmc_scatter.csv not found.
# 1712 h0_mcmc_scatter.csv not found.
# 1713 h0_mcmc_scatter.csv not found.
# 1714 h0_mcmc_scatter.csv not found.
# 1715 h0_mcmc_scatter.csv not found.
# 1716 h0_mcmc_scatter.csv not found.
# 1717 h0_mcmc_scatter.csv not found.
# 1718 h0_mcmc_scatter.csv not found.
# 1719 h0_mcmc_scatter.csv not found.
# 1720 h0_mcmc_scatter.csv not found.
# 1721 h0_mcmc_scatter.csv not found.
# 1722 h0_mcmc_scatter.csv not found.
# 1723 h0_mcmc_scatter.csv not found.
# 1724 h0_mcmc_scatter.csv not found.
# 1725 h0_mcmc_scatter.csv not found.
# 1726 h0_mcmc_scatter.csv not found.
# 1727 h0_mcmc_scatter.csv not found.
#      scaling_relation     delta  delta_err_lower  delta_err_upper        vlon  \
# 0                LX-T  0.044489         0.029309         0.032752  -48.021817
# 1               YSZ-T  0.022074         0.014781         0.019891 -119.937162
# 2                LX-T  0.028688         0.019354         0.022638  -12.002991
# 3               YSZ-T  0.020565         0.014369         0.020016  -83.968204
# 4                LX-T  0.021192         0.014550         0.022147   71.980186
# ...               ...       ...              ...              ...         ...
# 3186             LX-T  0.020767         0.014662         0.022274  -59.957726
# 3187            YSZ-T  0.022949         0.015072         0.019800  -83.976872
# 3188             LX-T  0.070387         0.026518         0.027209  107.828373
# 3189            YSZ-T  0.030179         0.017808         0.019115   71.902281
# 3190             LX-T  0.035440         0.023380         0.028492  131.997933
#
#       vlon_err_lower  vlon_err_upper       vlat  vlat_err_lower  \
# 0          38.028336       42.020201  -8.287346       29.513930
# 1         147.365447       61.635264 -35.817501       34.789693
# 2          97.655484       83.190884  42.861932       40.621710
# 3          81.233740       85.662503 -29.764978       39.517611
# 4          98.737039      109.869115  33.498121       55.714631
# ...              ...             ...        ...             ...
# 3186      112.086471       94.764450 -30.130739       40.692897
# 3187       90.569438       63.459138 -32.020557       37.416567
# 3188       81.512307       24.875303 -36.695605       24.474779
# 3189       91.284999       70.326077 -50.060321       27.001697
# 3190       94.654679       43.818582 -28.283561       37.835040
#
#       vlat_err_upper  convergence_time  Lightcone
# 0          29.140801         86.123327          0
# 1          42.111579         94.384478          0
# 2          31.590582         84.194876          1
# 3          46.645611        100.796751          1
# 4          38.514467        100.586012          2
# ...              ...               ...        ...
# 3186       54.554499         90.452391       1594
# 3187       39.152046         96.784388       1594
# 3188       18.329185          0.000000       1595
# 3189       34.032094         97.150902       1595
# 3190       32.350622          0.000000       1596
#
# [3191 rows x 12 columns]

# %%
# Get the significance
significance = data['delta'] / data['delta_err_lower']
data['Significance'] = significance
data['DeltaH0'] = data['delta'] * 2 * 100 # to percentage

# %%
data.to_csv('../data/analysis_all/h0_mc_scatter.csv')

# %% [markdown]
# ## Plot

# %%
import pandas as pd
data = pd.read_csv('../data/analysis_all/h0_mc_scatter.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.style.use('./nice.mplstyle')

colors = ['#348ABD', '#A60628', '#467821']
sns.set_palette(colors)
# Create the 2D KDE plot
g = sns.JointGrid(data=data, 
                    x='Significance',
                    y='DeltaH0', 
                    hue='scaling_relation',
                    space=0,
                    ratio=4,
                    # marginal_ticks=True,
                    height=5,
                    # dpi=300
                    xlim=(0.5, 4.0),
                    ylim=(-2.8, 20),
                    )

# kde plot missing 3rd level contour if use g.plot_joint, for unknown reason
for relation, color in zip(['LX-T', 'YSZ-T', 'M-T'], 
                            colors):
    
    sns.kdeplot(data=data[data['scaling_relation'] == relation], 
                x='Significance',
                y='DeltaH0', 
                #hue='Relations',
                color=color,
                fill=False, 
                levels=(0.011, 0.14, 0.61, 1.),
                bw_adjust=3.,
                zorder=1,
                ax=g.ax_joint
                )
    sns.kdeplot(data=data[data['scaling_relation'] == relation], 
                x='Significance',
                y='DeltaH0', 
                #hue='Relations',
                color=color,
                fill=True, 
                levels=(0.011, 0.14, 0.61, 1.), # 3 sigma is 0.011
                bw_adjust=3.,
                zorder=2,
                alpha=0.4,
                ax=g.ax_joint,
                )

# plot marginal plots
g.plot_marginals(sns.kdeplot,
                fill=False
                )

# M21 results
x_point = 2.4
y_point = 8.7
g.refline(x=x_point, y=y_point, linestyle='solid', color='b', zorder=3, linewidth=.8)
line0 = g.ax_joint.scatter(x_point, y_point, marker='o', facecolors='none', linewidth=.8, edgecolors='b', s=50, linewidths=1 ,label='$L_\\mathrm{{X}}-T$', zorder=10)

x_point = 2.6
y_point = 14
g.refline(x=x_point, y=y_point, linestyle='solid', color='r', zorder=3, linewidth=.8)
line1 = g.ax_joint.scatter(x_point, y_point, marker='o', facecolors='none', linewidth=.8, edgecolors='r', s=50, linewidths=1 ,label='$Y_\\mathrm{{SZ}}-T$', zorder=10)

# Also add the box for the marginal plots
g.ax_marg_x.spines['top'].set_visible(True)
g.ax_marg_x.spines['right'].set_visible(True)
g.ax_marg_x.spines['left'].set_visible(True)
g.ax_marg_x.spines['bottom'].set_visible(True)

g.ax_marg_y.spines['top'].set_visible(True)
g.ax_marg_y.spines['right'].set_visible(True)
g.ax_marg_y.spines['left'].set_visible(True)
g.ax_marg_y.spines['bottom'].set_visible(True)

# # matplotlib doesn't detect the contour correctly, adding it manually
# import matplotlib.patches as mpatches
# contour = mpatches.Patch(color='tab:blue', label='$Y_\\mathrm{{SZ}}-T$')
g.ax_marg_x.legend(handles=[line0, line1], title='Migkas+21', loc='upper right', bbox_to_anchor=(1,0), fontsize=9) # put right corner at 1,0

#sns.move_legend(g.ax_joint, loc='upper right', bbox_to_anchor=(1.7, 0.75), title='FLAMINGO')
from matplotlib.patches import Patch
# Create custom legend for contours
contour_legend_elements = [Patch(facecolor='#348ABD', edgecolor='#348ABD', label='$L_\\mathrm{X}-T$', alpha=0.5),
                           Patch(facecolor='#A60628', edgecolor='#A60628', label='$Y_\\mathrm{SZ}-T$', alpha=0.5),
                           Patch(facecolor='#467821', edgecolor='#467821', label='$M_\\mathrm{gas}-T$', alpha=0.5)]

# Add the custom legend for contours
g.ax_joint.legend(handles=contour_legend_elements, title='FLAMINGO', loc='upper left', fontsize=9)

# plt.savefig('./to_paper/h0mc_zcos_LTYTMT.pdf', bbox_inches='tight')
# Show the plot
plt.show()
