# %% [markdown]
# # Plot the full sky best fit behaviours
# The temperature used is the Chandra temperature. As default by the M21 analysis.

# %%
import os
import pandas as pd
import numpy as np

data_dir = '/cosma8/data/do012/dc-he4/analysis'
all_data = []

for lc in range(1728):
    lc00 = f'{lc:04d}'
    filename = f'{data_dir}/lc{lc00}/fit_all_scatter.csv'
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        df['Lightcone'] = lc
        all_data.append(df)

# Concatenate all dataframes
df = pd.concat(all_data, ignore_index=True)

# %%
# Write the concatenated dataframe to a CSV file
output_filename = f'/cosma8/data/do012/dc-he4/analysis_all/concatenated_fit_all_scatter.csv'
df.to_csv(output_filename, index=False)

# %% [markdown]
# Read and get data

# %%
import pandas as pd
df = pd.read_csv('/cosma8/data/do012/dc-he4/analysis_all/concatenated_fit_all_scatter.csv')
df
# Out:
#      Relation  BestFitA  BestFitB  BestFitScat  1SigmaUpperA  1SigmaLowerA  \
# 0        LX-T  1.753881     2.248        0.228      1.803018      1.690441
# 1       YSZ-T  1.071519     2.421        0.138      1.096478      1.042317
# 2        LX-T  1.737801     2.185        0.222      1.786488      1.674943
# 3       YSZ-T  1.076465     2.400        0.162      1.106624      1.047129
# 4        LX-T  1.745822     2.200        0.240      1.794734      1.682674
# ...       ...       ...       ...          ...           ...           ...
# 3216     LX-T  1.770109     2.131        0.246      1.803018      1.698244
# 3217    YSZ-T  1.086426     2.412        0.156      1.116863      1.056818
# 3218     LX-T  1.786488     2.296        0.222      1.853532      1.745822
# 3219    YSZ-T  1.056818     2.466        0.168      1.081434      1.018591
# 3220     LX-T  1.753881     2.239        0.234      1.794734      1.698244
#
#       1SigmaUpperB  1SigmaLowerB  1SigmaUpperScat  1SigmaLowerScat  Lightcone
# 0          2.32000       2.15500           0.2400            0.210          0
# 1          2.47800       2.36400           0.1440            0.120          0
# 2          2.29600       2.10700           0.2340            0.204          1
# 3          2.45757       2.33400           0.1740            0.150          1
# 4          2.26048       2.12752           0.2460            0.216          2
# ...            ...           ...              ...              ...        ...
# 3216       2.19161       2.03800           0.2586            0.228       1609
# 3217       2.45400       2.34000           0.1620            0.132       1609
# 3218       2.38000       2.21800           0.2280            0.204       1610
# 3219       2.52900       2.40900           0.1740            0.144       1610
# 3220       2.31400       2.15461           0.2460            0.222       1611
#
# [3221 rows x 11 columns]

# %%
df.drop_duplicates()
# Out:
#      Relation  BestFitA  BestFitB  BestFitScat  1SigmaUpperA  1SigmaLowerA  \
# 0        LX-T  1.753881     2.248        0.228      1.803018      1.690441
# 1       YSZ-T  1.071519     2.421        0.138      1.096478      1.042317
# 2        LX-T  1.737801     2.185        0.222      1.786488      1.674943
# 3       YSZ-T  1.076465     2.400        0.162      1.106624      1.047129
# 4        LX-T  1.745822     2.200        0.240      1.794734      1.682674
# ...       ...       ...       ...          ...           ...           ...
# 3216     LX-T  1.770109     2.131        0.246      1.803018      1.698244
# 3217    YSZ-T  1.086426     2.412        0.156      1.116863      1.056818
# 3218     LX-T  1.786488     2.296        0.222      1.853532      1.745822
# 3219    YSZ-T  1.056818     2.466        0.168      1.081434      1.018591
# 3220     LX-T  1.753881     2.239        0.234      1.794734      1.698244
#
#       1SigmaUpperB  1SigmaLowerB  1SigmaUpperScat  1SigmaLowerScat  Lightcone
# 0          2.32000       2.15500           0.2400            0.210          0
# 1          2.47800       2.36400           0.1440            0.120          0
# 2          2.29600       2.10700           0.2340            0.204          1
# 3          2.45757       2.33400           0.1740            0.150          1
# 4          2.26048       2.12752           0.2460            0.216          2
# ...            ...           ...              ...              ...        ...
# 3216       2.19161       2.03800           0.2586            0.228       1609
# 3217       2.45400       2.34000           0.1620            0.132       1609
# 3218       2.38000       2.21800           0.2280            0.204       1610
# 3219       2.52900       2.40900           0.1740            0.144       1610
# 3220       2.31400       2.15461           0.2460            0.222       1611
#
# [3221 rows x 11 columns]

# %%
for relation in ['LX-T', 'YSZ-T']:
    mask = df['Relation'] == relation
    masked_df = df[mask]
    print(relation)
    for key in ['BestFitA', 'BestFitB', 'BestFitScat']:
        arr = masked_df[key].values
        median = np.median(arr)
        eightyfourth = np.percentile(arr, 84)
        sixteenth = np.percentile(arr, 16)
        print(f'{key} = {median:.3f} +{eightyfourth - median:.3f} -{median - sixteenth:.3f}')
# Out:
# LX-T
# BestFitA = 1.762 +0.049 -0.040
# BestFitB = 2.215 +0.078 -0.084
# BestFitScat = 0.240 +0.018 -0.018
# YSZ-T
# BestFitA = 1.081 +0.030 -0.025
# BestFitB = 2.445 +0.054 -0.051
# BestFitScat = 0.156 +0.012 -0.012
