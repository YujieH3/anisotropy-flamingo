# %% [markdown]
# We check the data structure; write a function to load it as a dataframe;
# and make cut and compare to the real ones.

# %% [markdown]
# **1. Data structure**

# %%
import h5py

def h5ls(f):
    if type(f) == h5py._hl.dataset.Dataset:
        print(f, f[:10])
    else:
        print(f.keys())
        for key in f.keys():
            h5ls(f[key])

with h5py.File('../data/mock_lightcone/halo_lightcone_catalogue/halo_properties_in_lightcones.hdf5', 'r') as f:
    h5ls(f)
# Out:
# <KeysViewHDF5 ['lightcone0000']>
# <KeysViewHDF5 ['GalaxyID', 'GasMass', 'LX0InRestframeWithoutRecentAGNHeating', 'LX0InRestframeWithoutRecentAGNHeatingCoreExcision', 'LX0WithoutRecentAGNHeating', 'LX0WithoutRecentAGNHeatingCoreExcision', 'M500', 'M_fof_lc', 'MfofSOAP', 'SOAPID', 'SpectroscopicLikeTemperatureWithoutRecentAGNHeatingCoreExcision', 'TopLeafID', 'Vx', 'Vy', 'Vz', 'Y5R500WithoutRecentAGNHeating', 'phi_on_lc', 'redshift', 'snap_num', 'theta_on_lc', 'x_lc', 'y_lc', 'z_lc']>
# <HDF5 dataset "GalaxyID": shape (134286,), type "<i8"> [925930949 496435074  79992837 852524320 817871995 504508668 837145724
#  519087878 352882225 718970137]
# <HDF5 dataset "GasMass": shape (134286,), type "<f4"> [1.5762530e+12 2.1125870e+11 3.9621073e+11 2.4615531e+11 1.5784005e+11
#  3.7924561e+12 6.9041599e+11 9.6636764e+10 1.8253611e+11 2.4642375e+11]
# <HDF5 dataset "LX0InRestframeWithoutRecentAGNHeating": shape (134286,), type "<f8"> [3.74582830e+42 5.15868068e+41 4.65506278e+41 4.97492820e+41
#  1.94981796e+41 1.74224572e+43 2.46092208e+42 7.22249324e+40
#  2.27648903e+41 6.88050946e+41]
# <HDF5 dataset "LX0InRestframeWithoutRecentAGNHeatingCoreExcision": shape (134286,), type "<f8"> [3.48449144e+42 4.28755782e+41 4.65506278e+41 3.06254130e+41
#  1.94981796e+41 1.19561612e+43 8.99706578e+41 4.43217783e+40
#  2.27648903e+41 3.80435686e+41]
# <HDF5 dataset "LX0WithoutRecentAGNHeating": shape (134286,), type "<f8"> [3.75127281e+42 4.94770562e+41 4.47811595e+41 4.85242655e+41
#  1.84433043e+41 1.80104651e+43 2.30303106e+42 6.93325323e+40
#  2.19141844e+41 6.73078522e+41]
# <HDF5 dataset "LX0WithoutRecentAGNHeatingCoreExcision": shape (134286,), type "<f8"> [3.50082499e+42 4.11061099e+41 4.47811595e+41 2.91281706e+41
#  1.84433043e+41 1.24570569e+43 8.73845118e+41 4.30882547e+40
#  2.19141844e+41 3.70227215e+41]
# <HDF5 dataset "M500": shape (134286,), type "<f4"> [3.3225867e+13 6.8547678e+12 1.2335146e+13 1.0170483e+13 6.9234873e+12
#  5.7037166e+13 1.8107582e+13 7.3787538e+12 9.1568703e+12 1.0273562e+13]
# <HDF5 dataset "M_fof_lc": shape (134286,), type "<f8"> [5.46422500e+13 1.44862932e+13 2.39600822e+13 1.63409548e+13
#  1.17804945e+13 9.74621300e+13 3.08290711e+13 1.11792574e+13
#  1.68171797e+13 1.94614492e+13]
# <HDF5 dataset "MfofSOAP": shape (134286,), type "<f4"> [5.4631984e+13 1.4482630e+13 2.3948738e+13 1.6338056e+13 1.1785390e+13
#  9.7444218e+13 3.0820685e+13 1.1184095e+13 1.6819092e+13 1.9447612e+13]
# <HDF5 dataset "SOAPID": shape (134286,), type "<u8"> [107540 108177 547901 548236 548611 766977 767214 767907 861540 861582]
# <HDF5 dataset "SpectroscopicLikeTemperatureWithoutRecentAGNHeatingCoreExcision": shape (134286,), type "<f4"> [10633216.  4284416.  6045696.  5079040.  4227072. 17694720.  7020544.
#   4169728.  4235264.  6389760.]
# <HDF5 dataset "TopLeafID": shape (134286,), type "<i8"> [925931017 496435126  79992903 852524392 817872061 504508737 837145788
#  519087944 352882286 718970201]
# <HDF5 dataset "Vx": shape (134286,), type "<f4"> [-317.6078  -357.48004 -333.43933 -258.75098 -380.25098 -398.3006
#  -449.7273  -369.7273  -255.62988 -504.32983]
# <HDF5 dataset "Vy": shape (134286,), type "<f4"> [ -99.60779  -112.380066 -135.0393   -276.651    -116.151     -54.100586
#  -160.32727  -188.7273   -209.12988  -351.52985 ]
# <HDF5 dataset "Vz": shape (134286,), type "<f4"> [-103.407776  -77.380066  -25.539307  163.64905   -83.85095  -100.00055
#   -39.427307  -76.82727   -11.42981  -247.92987 ]
# <HDF5 dataset "Y5R500WithoutRecentAGNHeating": shape (134286,), type "<f8"> [7.87277284e+42 5.89369060e+41 1.51085371e+42 9.11956743e+41
#  4.77756443e+41 1.88815880e+43 2.22953007e+42 4.20589006e+41
#  1.02765275e+42 1.45640853e+42]
# <HDF5 dataset "phi_on_lc": shape (134286,), type "<f8"> [  46.00502466   45.06349227  -44.9041409   -45.73544563  -45.26685994
#   -43.86727085 -134.58873085 -134.50012303   45.95611507   45.92739824]
# <HDF5 dataset "redshift": shape (134286,), type "<f8"> [0.20263322 0.20444071 0.20016163 0.2019084  0.200741   0.20136511
#  0.20280973 0.20442253 0.20250373 0.20284905]
# <HDF5 dataset "snap_num": shape (134286,), type "<i8"> [73 73 73 73 73 73 73 73 73 73]
# <HDF5 dataset "theta_on_lc": shape (134286,), type "<f8"> [ 35.07975239  34.49431494  35.12657878  35.03142143  35.05580037
#   34.90355326  34.78601392  35.71782193 -35.58321342 -35.47669953]
# <HDF5 dataset "x_lc": shape (134286,), type "<f8"> [ 482.73011411  498.55820411  486.26840666  483.71718232  484.93865666
#   499.14211666 -490.0400022  -487.3254122   479.86549411  481.52946411]
# <HDF5 dataset "y_lc": shape (134286,), type "<f8"> [ 499.96940411  499.66438411 -484.64401334 -496.29728768 -489.47711334
#  -479.78632334 -497.1260022  -495.9038122   496.15419411  497.37555411]
# <HDF5 dataset "z_lc": shape (134286,), type "<f8"> [ 488.07359411  485.01442411  482.98413666  485.83283232  483.46015666
#   483.04846666  484.9045578   499.9334278  -493.86195589 -493.37463589]

# %%
# revert the file to before _d_comebine_lightcone
with h5py.File('../data/halo_properties_in_lightcones.hdf5', 'a') as f:
    for name in f['lightcone0000'].keys():
        if name[:4] != 'Snap':
            del f[f'lightcone0000/{name}']

# %% [markdown]
# **2. Load as a dataframe**

# %%
import numpy as np
import pandas as pd

def load_lightcone(filename, lightcone_num):
    """
    Return the observers x, y, z coord in cMpc, and a dataset containing
    the list of halo properties.

    Note
    --
    The coordinates here ranges from 0 to L instead of -L/2 to L/2, different to 
    """
    dict = {}
    with h5py.File(filename, 'r') as f:
        lc = f'lightcone{lightcone_num:04d}'
        for qty_key, qty_dataset in f[lc].items():
            if qty_key in dict.keys():
                dict[qty_key] = np.concatenate((dict[qty_key], qty_dataset[:]))
            else:
                dict[qty_key] = qty_dataset[:]

        Xobs = f[lc].attrs['Xobs']
        Yobs = f[lc].attrs['Yobs']
        Zobs = f[lc].attrs['Zobs']

    # for output
    XYZobs = np.array([Xobs, Yobs, Zobs])
    catalogue = pd.DataFrame(dict)
    return XYZobs, catalogue

obs_coord, cat = load_lightcone(filename='../data/halo_properties_in_lightcones.hdf5', lightcone_num=0)

# %%
obs_coord
# Out:
# array([750., 750., 750.])

# %%
cat
# Out:
#          GalaxyID       GasMass  LX0InRestframeWithoutRecentAGNHeating  \
# 0       925930949  1.576253e+12                           3.745828e+42
# 1       496435074  2.112587e+11                           5.158681e+41
# 2        79992837  3.962107e+11                           4.655063e+41
# 3       852524320  2.461553e+11                           4.974928e+41
# 4       817871995  1.578400e+11                           1.949818e+41
# ...           ...           ...                                    ...
# 134281  740659177  8.576513e+10                           6.048519e+40
# 134282  472785622  1.288490e+11                           5.912406e+40
# 134283  287556330  8.979166e+10                           3.385810e+40
# 134284   69803936  7.865159e+10                           3.772881e+40
# 134285  837063011  1.158299e+11                           6.201646e+40
#
#         LX0InRestframeWithoutRecentAGNHeatingCoreExcision  \
# 0                                            3.484491e+42
# 1                                            4.287558e+41
# 2                                            4.655063e+41
# 3                                            3.062541e+41
# 4                                            1.949818e+41
# ...                                                   ...
# 134281                                       4.372628e+40
# 134282                                       3.287978e+40
# 134283                                       3.385810e+40
# 134284                                       2.543611e+40
# 134285                                       6.201646e+40
#
#         LX0WithoutRecentAGNHeating  LX0WithoutRecentAGNHeatingCoreExcision  \
# 0                     3.751273e+42                            3.500825e+42
# 1                     4.947706e+41                            4.110611e+41
# 2                     4.478116e+41                            4.478116e+41
# 3                     4.852427e+41                            2.912817e+41
# 4                     1.844330e+41                            1.844330e+41
# ...                            ...                                     ...
# 134281                5.988970e+40                            4.325840e+40
# 134282                5.844350e+40                            3.198654e+40
# 134283                3.334767e+40                            3.334767e+40
# 134284                3.696317e+40                            2.488315e+40
# 134285                6.108068e+40                            6.108068e+40
#
#                 M500      M_fof_lc      MfofSOAP    SOAPID  ...          Vy  \
# 0       3.322587e+13  5.464225e+13  5.463198e+13    107540  ...  -99.607788
# 1       6.854768e+12  1.448629e+13  1.448263e+13    108177  ... -112.380066
# 2       1.233515e+13  2.396008e+13  2.394874e+13    547901  ... -135.039307
# 3       1.017048e+13  1.634095e+13  1.633806e+13    548236  ... -276.651001
# 4       6.923487e+12  1.178049e+13  1.178539e+13    548611  ... -116.151001
# ...              ...           ...           ...       ...  ...         ...
# 134281  5.944235e+12  1.028671e+13  1.029074e+13  13331286  ...  -59.374634
# 134282  6.622840e+12  1.059169e+13  1.059998e+13  13331331  ... -139.774597
# 134283  6.614250e+12  1.031581e+13  1.030792e+13  13331328  ... -183.374634
# 134284  5.729486e+12  1.025946e+13  1.025638e+13  13219519  ...  -83.838013
# 134285  6.519760e+12  1.033984e+13  1.034228e+13  13331407  ...  -22.774658
#
#                 Vz  Y5R500WithoutRecentAGNHeating  phi_on_lc  redshift  \
# 0      -103.407776                   7.872773e+42  35.079752  0.202633
# 1       -77.380066                   5.893691e+41  34.494315  0.204441
# 2       -25.539307                   1.510854e+42  35.126579  0.200162
# 3       163.649048                   9.119567e+41  35.031421  0.201908
# 4       -83.850952                   4.777564e+41  35.055800  0.200741
# ...            ...                            ...        ...       ...
# 134281  -71.474609                   2.626980e+41  72.372207  0.030784
# 134282 -204.874634                   2.188016e+41  62.347162  0.045958
# 134283  -34.674561                   2.075722e+41  60.006044  0.038558
# 134284  101.361938                   1.776274e+41  66.947945  0.031261
# 134285  -73.674561                   1.973638e+41  56.413440  0.046220
#
#         snap_num  theta_on_lc        x_lc        y_lc        z_lc
# 0             73    46.005025  482.730114  499.969404  488.073594
# 1             73    45.063492  498.558204  499.664384  485.014424
# 2             73   -44.904141  486.268407 -484.644013  482.984137
# 3             73   -45.735446  483.717182 -496.297288  485.832832
# 4             73   -45.266860  484.938657 -489.477113  483.460157
# ...          ...          ...         ...         ...         ...
# 134281        76    85.665792    3.080619   40.646339  128.285039
# 134282        76    16.013698   89.312552   25.633072  177.337552
# 134283        76    35.523963   68.434924   48.857354  145.675934
# 134284        76    83.622434    5.940499   53.148599  125.672369
# 134285        76     7.297031  110.461428   14.144618  167.700658
#
# [134286 rows x 23 columns]

# %% [markdown]
# **3. Compare to our sample**

# %%
import pandas as pd
df = pd.read_hdf('../data/halo_properties_in_lightcone0.hdf5', key='lightcone', mode='r')
df
# Out:
#              lc_id  redshift  theta_on_lc  phi_on_lc      M_fof_lc  \
# 0         13494138  0.289412     2.434740  46.845344  5.089802e+12
# 1         13492844  0.288434     2.159398  47.195837  1.007841e+13
# 2         13493475  0.287379     2.838580  47.159344  6.340263e+12
# 3         13492385  0.285515     2.281295  47.353490  1.101831e+13
# 4         13493858  0.279886     3.055411  45.777673  5.561836e+12
# ...            ...       ...          ...        ...           ...
# 12194113   7422479  0.127782    -2.290613 -46.849291  5.109128e+12
# 12194114   7421622  0.127696    -2.282832 -46.711938  7.941985e+12
# 12194115   7420256  0.127743    -2.912506 -44.372803  2.831814e+13
# 12194116   7421463  0.128083    -2.978288 -43.864296  8.746282e+12
# 12194117   7422161  0.125791    -2.585445 -45.601706  5.512498e+12
#
#                 x_lc        y_lc       z_lc  snap_num      MfofSOAP  ...  \
# 0         810.524940  864.491405  50.387261        71  5.093831e+12  ...
# 1         802.852393  866.875374  44.551823        71  1.008458e+13  ...
# 2         800.310973  863.028035  58.359069        71  6.339372e+12  ...
# 3         792.932866  860.904376  46.626492        71  1.101230e+13  ...
# 4         800.853042  822.893445  61.291777        71  5.557688e+12  ...
# ...              ...         ...        ...       ...           ...  ...
# 12194113  372.898101 -397.781361 -21.809497        74  5.111011e+12  ...
# 12194114  373.292331 -396.293601 -21.702877        74  7.945690e+12  ...
# 12194115  389.670885 -381.231748 -27.735059        74  2.831242e+13  ...
# 12194116  393.683956 -378.378307 -28.409139        74  8.744553e+12  ...
# 12194117  375.547031 -383.518848 -24.237958        74  5.514738e+12  ...
#
#           LX0WithoutRecentAGNHeating  LX0InRestframeWithoutRecentAGNHeating  \
# 0                       0.000000e+00                           0.000000e+00
# 1                       5.257363e+40                           7.749931e+40
# 2                       0.000000e+00                           0.000000e+00
# 3                       3.375601e+41                           3.688661e+41
# 4                       2.930682e+40                           3.555951e+40
# ...                              ...                                    ...
# 12194113                6.388801e+40                           6.984296e+40
# 12194114                2.113153e+41                           2.191418e+41
# 12194115                2.136973e+42                           2.139696e+42
# 12194116                0.000000e+00                           0.000000e+00
# 12194117                1.484482e+40                           1.590820e+40
#
#           LX0WithoutRecentAGNHeatingCoreExcision  \
# 0                                   0.000000e+00
# 1                                   4.423671e+40
# 2                                   0.000000e+00
# 3                                   3.375601e+41
# 4                                   2.922175e+40
# ...                                          ...
# 12194113                            6.380294e+40
# 12194114                            9.017483e+40
# 12194115                            1.246795e+42
# 12194116                            0.000000e+00
# 12194117                            1.484482e+40
#
#           LX0InRestframeWithoutRecentAGNHeatingCoreExcision  \
# 0                                              0.000000e+00
# 1                                              6.142097e+40
# 2                                              0.000000e+00
# 3                                              3.688661e+41
# 4                                              3.547444e+40
# ...                                                     ...
# 12194113                                       6.975789e+40
# 12194114                                       9.323737e+40
# 12194115                                       1.253600e+42
# 12194116                                       0.000000e+00
# 12194117                                       1.590820e+40
#
#           GasTemperatureWithoutRecentAGNHeatingCoreExcision  \
# 0                                                       0.0
# 1                                                 2473984.0
# 2                                                       0.0
# 3                                                 2629632.0
# 4                                                 1148928.0
# ...                                                     ...
# 12194113                                          1020928.0
# 12194114                                          3502080.0
# 12194115                                          7872512.0
# 12194116                                                0.0
# 12194117                                           774144.0
#
#           SpectroscopicLikeTemperatureWithoutRecentAGNHeatingCoreExcision  \
# 0                                                       0.0
# 1                                                 2224128.0
# 2                                                       0.0
# 3                                                 5652480.0
# 4                                                 3170304.0
# ...                                                     ...
# 12194113                                          2842624.0
# 12194114                                          3702784.0
# 12194115                                          7806976.0
# 12194116                                                0.0
# 12194117                                          2830336.0
#
#           Y5R500WithoutRecentAGNHeating          Vx          Vy         Vz
# 0                          0.000000e+00  -13.873657  136.326300 -286.77368
# 1                          2.715453e+41 -189.534910   68.665040 -146.43494
# 2                          0.000000e+00 -194.329100   32.970947 -198.32910
# 3                          3.586576e+41 -226.034910  166.265140 -223.23492
# 4                          6.031505e+40 -238.429080  -55.829100 -228.42908
# ...                                 ...         ...         ...        ...
# 12194113                   1.175676e+41  157.193000  -96.707030  507.99304
# 12194114                   2.688231e+41   50.399048 -243.600950  405.79895
# 12194115                   1.973638e+42 -160.425900 -243.125920  335.87415
# 12194116                   0.000000e+00 -207.100950 -355.601000  286.29895
# 12194117                   1.104216e+41  -19.607056  -90.906980  359.09302
#
# [12194118 rows x 23 columns]

# %%
# Extract the overlaps
true_soapid = df['SOAPID'].values
true_snapnum = df['snap_num'].values

mock_soapid = cat['SOAPID'].values
mock_snapnum = cat['snap_num'].values

# the halos from mock lightcones that are in the halo lightcones
mock_overlap_mask = np.isin(mock_soapid, true_soapid) & np.isin(mock_snapnum, true_snapnum)
mock_overlap = cat[mock_overlap_mask]

# the halos from halo_lightcones that are in our mock samples
true_overlap_mask = np.isin(true_soapid, mock_soapid) & np.isin(true_snapnum, mock_snapnum)
true_overlap = df[true_overlap_mask]

print(len(mock_overlap), len(true_overlap))

mock_overlap.sort_values(by='redshift', inplace=True)
mock_overlap = mock_overlap.drop_duplicates(subset=['SOAPID', 'snap_num'], keep='first') 

true_overlap.sort_values(by='redshift', inplace=True)
true_overlap = true_overlap.drop_duplicates(subset=['SOAPID', 'snap_num'], keep='first')

print(len(mock_overlap), len(true_overlap))
# Out:
# 131831 198259
# 131831 138563
# /var/tmp/yujiehe/ipykernel_293268/3194599748.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mock_overlap.sort_values(by='redshift', inplace=True)
# /var/tmp/yujiehe/ipykernel_293268/3194599748.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true_overlap.sort_values(by='redshift', inplace=True)

# %%
mock_overlap
# Out:
#          GalaxyID       GasMass  LX0InRestframeWithoutRecentAGNHeating  \
# 130392  135974422  1.069715e+11                           1.301580e+41
# 132347  685132241  1.777043e+11                           8.847342e+40
# 131131  698818846  2.450816e+11                           1.259045e+41
# 130071  633280161  1.290638e+12                           1.529910e+42
# 130349  760442232  1.758252e+11                           9.851175e+40
# ...           ...           ...                                    ...
# 6       837145724  6.904160e+11                           2.460922e+42
# 9       718970137  2.464237e+11                           6.880509e+41
# 14      383816326  5.626407e+11                           1.480909e+42
# 7       519087878  9.663676e+10                           7.222493e+40
# 1       496435074  2.112587e+11                           5.158681e+41
#
#         LX0InRestframeWithoutRecentAGNHeatingCoreExcision  \
# 130392                                       5.699730e+40
# 132347                                       6.516407e+40
# 131131                                       1.138245e+41
# 130071                                       1.294434e+42
# 130349                                       9.851175e+40
# ...                                                   ...
# 6                                            8.997066e+41
# 9                                            3.804357e+41
# 14                                           1.155599e+42
# 7                                            4.432178e+40
# 1                                            4.287558e+41
#
#         LX0WithoutRecentAGNHeating  LX0WithoutRecentAGNHeatingCoreExcision  \
# 130392                1.301580e+41                            5.699730e+40
# 132347                8.847342e+40                            6.516407e+40
# 131131                1.259045e+41                            1.138245e+41
# 130071                1.529910e+42                            1.294434e+42
# 130349                9.851175e+40                            9.851175e+40
# ...                            ...                                     ...
# 6                     2.303031e+42                            8.738451e+41
# 9                     6.730785e+41                            3.702272e+41
# 14                    1.486353e+42                            1.162405e+42
# 7                     6.933253e+40                            4.308825e+40
# 1                     4.947706e+41                            4.110611e+41
#
#                 M500      M_fof_lc      MfofSOAP    SOAPID  ...          Vy  \
# 130392  6.837588e+12  1.297204e+13  1.297080e+13  12092781  ...  236.147705
# 132347  9.277129e+12  1.418184e+13  1.417339e+13  12588009  ...   81.430237
# 131131  1.068588e+13  1.628107e+13  1.628652e+13  12307272  ...   -1.998352
# 130071  2.497953e+13  3.717857e+13  3.717724e+13  12092139  ...  281.847656
# 130349  7.138236e+12  1.425507e+13  1.425929e+13  12092675  ...  249.047729
# ...              ...           ...           ...       ...  ...         ...
# 6       1.810758e+13  3.082907e+13  3.082069e+13    767214  ... -160.327271
# 9       1.027356e+13  1.946145e+13  1.944761e+13    861582  ... -351.529846
# 14      1.745475e+13  3.190104e+13  3.188584e+13   1546718  ... -214.804810
# 7       7.378754e+12  1.117926e+13  1.118409e+13    767907  ... -188.727295
# 1       6.854768e+12  1.448629e+13  1.448263e+13    108177  ... -112.380066
#
#                 Vz  Y5R500WithoutRecentAGNHeating  phi_on_lc  redshift  \
# 130392 -193.052368                   2.912817e+41 -44.200430  0.005554
# 132347   94.230286                   3.416435e+41  15.659146  0.006138
# 131131 -109.498352                   6.771619e+41 -29.048466  0.006246
# 130071 -145.452271                   3.892830e+42 -52.096904  0.007459
# 130349  -80.252319                   4.641451e+41 -42.737751  0.007554
# ...            ...                            ...        ...       ...
# 6       -39.427307                   2.229530e+42  34.786014  0.202810
# 9      -247.929871                   1.456409e+42 -35.476700  0.202849
# 14     -148.304810                   3.223155e+42 -35.751800  0.203772
# 7       -76.827271                   4.205890e+41  35.717822  0.204423
# 1       -77.380066                   5.893691e+41  34.494315  0.204441
#
#         snap_num  theta_on_lc        x_lc        y_lc        z_lc
# 130392        77   101.516290   -3.494822   17.152638  -17.023172
# 132347        77   -13.677499   25.242591   -6.142979    7.282471
# 131131        77    91.303693   -0.546152   23.998618  -13.332652
# 130071        77   125.106145  -11.580822   16.474088  -25.864622
# 130349        77   136.712910  -17.747387   16.716743  -22.527637
# ...          ...          ...         ...         ...         ...
# 6             73  -134.588731 -490.040002 -497.126002  484.904558
# 9             73    45.927398  481.529464  497.375554 -493.374636
# 14            73  -133.845141 -479.966310 -499.715550 -498.835590
# 7             73  -134.500123 -487.325412 -495.903812  499.933428
# 1             73    45.063492  498.558204  499.664384  485.014424
#
# [131831 rows x 23 columns]

# %%
true_overlap
# Out:
#             lc_id  redshift  theta_on_lc   phi_on_lc      M_fof_lc  \
# 1590680  12092782  0.005547   -44.204207  101.430080  1.297204e+13
# 1589977  12588010  0.006131    15.646501  -13.688982  1.418184e+13
# 1589998  12307273  0.006290   -29.078361   91.299223  1.628107e+13
# 1589811  12589065  0.006897    71.891733  -24.967590  7.090135e+12
# 1590581  12092140  0.007605   -52.183898  125.038375  3.717857e+13
# ...           ...       ...          ...         ...           ...
# 1300387  10640579  0.224880    -3.880162   60.509737  6.256694e+12
# 1296683  10640215  0.224885    -7.514917   65.982099  8.673324e+12
# 1280606  12497979  0.224926   -14.921669   89.754234  6.837042e+12
# 1303845  11358510  0.224970     6.678292   63.028547  1.172043e+13
# 1546297  11358879  0.224979   -69.218475   -8.441790  9.954675e+12
#
#                x_lc        y_lc        z_lc  snap_num      MfofSOAP  ...  \
# 1590680   -3.464560   17.135870  -17.003580        77  1.297080e+13  ...
# 1589977   25.220365   -6.142925    7.270235        77  1.417339e+13  ...
# 1589998   -0.543224   23.952076  -13.323134        77  1.628652e+13  ...
# 1589811    8.608027   -4.008063   29.037037        77  7.086696e+12  ...
# 1590581  -11.539276   16.456324  -25.896306        77  3.717724e+13  ...
# ...             ...         ...         ...       ...           ...  ...
# 1300387  460.418854  814.110346  -63.436115        73  6.253472e+12  ...
# 1296683  378.087345  848.484564 -122.539525        73  8.675834e+12  ...
# 1280606    3.884969  905.701690 -241.357629        73  6.837588e+12  ...
# 1303845  422.401682  830.032085  109.048476        73  1.171667e+13  ...
# 1546297  329.040450  -48.833720 -876.544101        73  9.947144e+12  ...
#
#          LX0WithoutRecentAGNHeating  LX0InRestframeWithoutRecentAGNHeating  \
# 1590680                1.301580e+41                           1.301580e+41
# 1589977                8.847342e+40                           8.847342e+40
# 1589998                1.259045e+41                           1.259045e+41
# 1589811                1.184608e+40                           1.184608e+40
# 1590581                1.529910e+42                           1.529910e+42
# ...                             ...                                    ...
# 1300387                6.031505e+40                           9.357765e+40
# 1296683                5.572124e+40                           5.742265e+40
# 1280606                6.550436e+40                           9.766104e+40
# 1303845                2.058708e+41                           2.102945e+41
# 1546297                3.611247e+40                           3.943022e+40
#
#          LX0WithoutRecentAGNHeatingCoreExcision  \
# 1590680                            5.699730e+40
# 1589977                            6.516407e+40
# 1589998                            1.138245e+41
# 1589811                            1.097411e+40
# 1590581                            1.294434e+42
# ...                                         ...
# 1300387                            6.031505e+40
# 1296683                            2.679724e+40
# 1280606                            6.550436e+40
# 1303845                            1.711620e+41
# 1546297                            3.211415e+40
#
#          LX0InRestframeWithoutRecentAGNHeatingCoreExcision  \
# 1590680                                       5.699730e+40
# 1589977                                       6.516407e+40
# 1589998                                       1.138245e+41
# 1589811                                       1.097411e+40
# 1590581                                       1.294434e+42
# ...                                                    ...
# 1300387                                       9.357765e+40
# 1296683                                       2.892400e+40
# 1280606                                       9.766104e+40
# 1303845                                       1.759260e+41
# 1546297                                       3.560204e+40
#
#          GasTemperatureWithoutRecentAGNHeatingCoreExcision  \
# 1590680                                          3330048.0
# 1589977                                          4587520.0
# 1589998                                          6070272.0
# 1589811                                          1732608.0
# 1590581                                          9764864.0
# ...                                                    ...
# 1300387                                          2293760.0
# 1296683                                          2777088.0
# 1280606                                          1478656.0
# 1303845                                          5734400.0
# 1546297                                          2744320.0
#
#          SpectroscopicLikeTemperatureWithoutRecentAGNHeatingCoreExcision  \
# 1590680                                          3166208.0
# 1589977                                          4562944.0
# 1589998                                          6103040.0
# 1589811                                          2523136.0
# 1590581                                         10240000.0
# ...                                                    ...
# 1300387                                          2281472.0
# 1296683                                          3178496.0
# 1280606                                          2854912.0
# 1303845                                          5423104.0
# 1546297                                          3043328.0
#
#          Y5R500WithoutRecentAGNHeating          Vx          Vy          Vz
# 1590680                   2.912817e+41 -373.552370  236.147700 -193.052370
# 1589977                   3.416435e+41  254.930240   81.430240   94.230286
# 1589998                   6.771619e+41 -194.998350   -1.998352 -109.498350
# 1589811                   4.959615e+40  108.957340   43.157288  315.957340
# 1590581                   3.892830e+42 -424.152340  281.847660 -145.452270
# ...                                ...         ...         ...         ...
# 1300387                   9.425822e+40   72.302490  -18.297607   -9.497559
# 1296683                   1.114425e+41  -36.097534 -216.697570  -18.897583
# 1280606                   1.485333e+41  121.345580 -334.154420  463.945560
# 1303845                   1.813024e+42 -151.119260 -562.319300 -414.319270
# 1546297                   3.045527e+41 -176.619260  -33.719240  432.980700
#
# [138563 rows x 23 columns]
