# %%
# %load_ext autoreload
# %autoreload 2
import emcee
import numpy as np
import sys
sys.path.append('..')
import tools.constants as const
import tools.clusterfit as cf
from astropy.cosmology import FlatLambdaCDM
cosmo = FlatLambdaCDM(H0=68.1, Om0=0.306, Ob0=0.0486)

C = 299792.458                  # the speed of light in km/s


def log_likelihood(theta, X, Y, z_obs, phi_lc, theta_lc, yname, xname):
    """
    X, Y, z_obs, phi_lc, theta_lc, are from the data
    """
    lp = log_prior(theta)
    if not np.isfinite(lp):
       return -np.inf 
    
    delta, vlon, vlat, logA, B, sigma, = theta

    # Set the scaling relation to know the pivot point
    scaling_relation = f'{yname}-{xname}'

    # Calculate the redshift
    angle = cf.angular_separation(phi_lc, theta_lc, vlon, vlat) * np.pi/180
   
    H0_ratio = 1+delta*np.cos(angle)

    # Calculate the Luminosity distance
    if yname == 'LX':
        Y_mod = Y*H0_ratio**-2
    elif yname == 'YSZ':
        Y_mod = Y*H0_ratio**-2
    elif yname == 'M':
        Y_mod = Y*H0_ratio**(-5/2) # (DA_modified)**(5/2)/(DA_default)**(5/2)
        
    # To our fit parameters
    logY_ = cf.logY_(Y_mod, z=z_obs, relation=scaling_relation)
    logX_ = cf.logX_(X, relation=scaling_relation)

    model = B * logX_ + logA
    lnL = -0.5 * np.sum((logY_ - model) ** 2 / (sigma**2) + np.log(sigma**2)) # Kostas' implementation

    return lnL + lp

# set prior
def log_prior(theta):
    # A large flat prior for now
    delta, vlon, vlat, logA, B, sigma = theta # 6 parameters

    # If in range, p(theta)=1, else p(theta)=0
    if -1<logA<1 and 0.5<B<3.5 and 0.05<sigma<1 \
        and 0<delta<1 and -180<vlon<180 and -90<vlat<90:
        return 0.0
    else:
        return -np.inf
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
lc = 0
data = pd.read_csv(f'../data/samples_in_lightcone{lc}_with_trees_duplicate_excision_outlier_excision.csv')
data
# Out:
#         lc_id  redshift  theta_on_lc   phi_on_lc      M_fof_lc        x_lc  \
# 0    12678101  0.049663    68.444418 -146.100556  3.221621e+14  -65.892905
# 1    13217952  0.031250    61.242576   66.517408  2.121565e+14   26.197568
# 2    11897316  0.016130   -50.768598  -21.506782  9.199489e+13   41.950287
# 3    12785470  0.019369    28.752838  151.820271  1.019505e+14  -65.416111
# 4     6057316  0.077597   -74.324178 -132.555680  2.872746e+14  -61.330249
# ..        ...       ...          ...         ...           ...         ...
# 701  11804705  0.085544    22.449321  158.121013  5.532838e+14 -316.531368
# 702  11861703  0.028225   -55.011456 -126.277785  7.538000e+13  -41.823558
# 703   4646616  0.125712   -33.564085 -169.939991  8.079670e+14 -442.983802
# 704  12882763  0.052263    43.009397  -35.045370  1.727982e+14  135.647971
# 705  11897198  0.016366   -33.124879  -28.281435  3.261190e+14   53.345272
#
#            y_lc        z_lc  snap_num      MfofSOAP  ...  \
# 0    -44.277266  200.964592        76  3.221569e+14  ...
# 1     60.300376  119.801093        76  2.122057e+14  ...
# 2    -16.530393  -55.223603        77  9.194666e+13  ...
# 3     35.046019   40.719139        77  1.019797e+14  ...
# 4    -66.799779 -323.142433        75  2.875223e+14  ...
# ..          ...         ...       ...           ...  ...
# 701  127.109968  140.934807        75  5.530544e+14  ...
# 702  -56.982167 -100.989675        76  7.531655e+13  ...
# 703  -78.588470 -298.507096        74  8.081410e+14  ...
# 704  -95.141897  154.556921        76  1.728982e+14  ...
# 705  -28.701178  -39.526618        77  3.260052e+14  ...
#
#      Y5R500WithoutRecentAGNHeating         Vx          Vy          Vz  \
# 0                        13.394281 -138.41480  146.285160 -258.814820
# 1                         8.353127  136.95007   85.050050  156.950070
# 2                         1.736042 -143.69714 -196.297180  -29.697144
# 3                         2.198071 -126.92236  256.877560    1.177612
# 4                        12.424476  168.31421   95.214230   99.214230
# ..                             ...        ...         ...         ...
# 701                      77.584358  492.35680  242.556760   50.656740
# 702                       2.511428   98.96692 -309.533080 -453.733030
# 703                     140.383773 -671.88740   77.012570 -361.787350
# 704                      10.978919 -296.42468  159.875300  135.375300
# 705                      27.483893  143.50280   39.602783  100.902830
#
#       GalaxyID  TopLeafID  3DLcore/Ltot  ObservedRedshift          Flux  \
# 0    264729502  264729571      0.629913          0.048863  1.930583e-11
# 1    758729120  758729192      0.563404          0.031943  3.424318e-11
# 2    735257909  735257982      0.587601          0.016076  1.415207e-11
# 3    553518674  553518749      0.448886          0.020066  1.010312e-11
# 4    256178182  256178252      0.538358          0.077076  7.649637e-12
# ..         ...        ...           ...               ...           ...
# 701  795913407  795913476      0.020071          0.084388  2.813252e-11
# 702  261040288  261040362      0.020155          0.029877  7.749973e-12
# 703  690964560  690964632      0.002155          0.128495  6.101368e-12
# 704  583385361  583385430      0.011669          0.051729  5.409843e-12
# 705   30776977   30777043      0.001408          0.016484  1.030848e-10
#
#      2DLcore/Ltot
# 0        0.655002
# 1        0.619050
# 2        0.580910
# 3        0.540358
# 4        0.485846
# ..            ...
# 701      0.060460
# 702      0.057530
# 703      0.047056
# 704      0.042653
# 705      0.011050
#
# [706 rows x 29 columns]

# %%
# Load data
yname = 'M'
xname = 'T'
relation = f'{yname}-{xname}'
n_clusters = cf.CONST[relation]['N']
data  = data[:n_clusters]

# Load data
z_obs    = data['ObservedRedshift'].values
X        = data[cf.COLUMNS[xname]].values
Y        = data[cf.COLUMNS[yname]].values
phi_lc   = data['phi_on_lc'].values
theta_lc = data['theta_on_lc'].values

# %% [markdown]
# ## Use a Scipy solver for initial condition

# %%
from scipy.optimize import minimize
from scipy.optimize import differential_evolution
nll = lambda *args: -log_likelihood(*args)
initial = np.array([0, 0, 0, 1, 1, 0.1]) # initial guess
bounds = [(0, 0.09), (-180, 180), (-90, 90), (0.1, 1), (0.5, 3.5), (0.05, 1)]

soln = differential_evolution(nll, args=(X, Y, z_obs, phi_lc, theta_lc, yname, xname), 
                bounds=bounds, popsize=10, strategy='rand1bin')
print(soln.x)
# Out:
# [ 1.43969553e-02 -5.84325484e+01 -4.24961444e+00  1.02983851e-01
#   2.10620861e+00  9.36118755e-02]
# /Users/yujiehe/mambaforge/envs/plot/lib/python3.12/site-packages/scipy/optimize/_numdiff.py
#        3774761482, 4292628583,  132441199, 1633606863, 3265137855,
#        1061769989,  193561489, 1354469083, 1359068455, 2655604820,
#        2865247287, 1040791132, 1194851224, 4076571390, 3877716844,
#        2846563290, 1985952612, 2101987886, 1780622432, 2856982831,
#         444753188,  573099255, 1759775596, 1717340706, 3394933351,
#         976480384, 1756233970, 3607314359, 4117516408, 2091132699,
#        3233752905, 1275344259, 3312431843, 1176751384, 3085570172,
#        2721402110, 2936329989, 1064321000, 3816310073, 2825252131,
#         366816460, 3135456087, 2582017039, 2847348558,  681608599,
#        1237203069, 3546354033, 3949240143, 3311531423, 1858289860,
#        3819251822, 1456009070, 3607493285, 1608892990, 3910762031,
#         597553866, 2149969914, 1850901538, 2716624278,  729369688,
#         743784340,  414054864,  636587786, 2886099526, 2929345482,
#         629751589, 2264574540, 2642466899, 2433427613,  618260005,
#         835150457, 2334663871, 1908733526, 4060308499, 1769687555,
#         859975352, 1197867931, 1309513356, 4196081236, 3638000503,
#        3562167549, 2758149528, 4090049298, 2711241600], dtype=uint32), 491, 0, 0.0))

# %%
try:
    tau = sampler.get_autocorr_time()
    print(tau)
except emcee.autocorr.AutocorrError:
    print('The chain is too short to get a reliable autocorrelation time.')
    tau = 0
# Out:
# [114.99961238 139.16327611 106.22581849  85.28530936  91.02262564
#   85.54656929]

# %% [markdown]
# Throw away a few times this number of steps as “burn-in”. And thin by about half the autocorrelation time.

# %%
tau = sampler.get_autocorr_time()

# %%
flat_samples = sampler.get_chain(discard=1000, thin=60, flat=True)
print(flat_samples.shape)
# Out:
# (4800, 6)

# %%
import corner
import matplotlib.pyplot as plt

fig = corner.corner(
    flat_samples, 
    labels=['delta', 'lon', 'lat', 'logA', 'B', 'scatter'], 
    quantiles=[0.16, 0.5, 0.84],
    show_titles=True, 
    title_fmt='.3f',
    title_kwargs={"fontsize": 15},
    label_kwargs={"fontsize": 17},
    smooth=1,
    levels=[0.39],
)

# Title
fig.suptitle(f'{yname}-{xname}', fontsize=20)
# Out:
# Text(0.5, 0.98, 'M-T')

# %% [markdown]
# ## Interpretation of the results

# %%
# The highest probability values and the quantiles for vlon 
vlon_distr = flat_samples[:, 1].copy()
hist, edges = np.histogram(vlon_distr, bins=30, density=True)
peak_vlon = edges[np.argmax(hist)]

# Shift to peak=0 to avoid breaking near the edge
vlon_distr = (vlon_distr - peak_vlon - 180) % 360 - 180 # Despite the shift, keep the range in 180 to 180

# 34th percentile around the peak value
peak_percentile = np.sum(vlon_distr < 0) / len(vlon_distr) * 100
l = np.percentile(vlon_distr, peak_percentile - 34)
u = np.percentile(vlon_distr, peak_percentile + 34)

# Convert back to the original coordinates
lower_vlon = (l + peak_vlon + 180) % 360 - 180
upper_vlon = (u + peak_vlon + 180) % 360 - 180
print(f'vlon: {lower_vlon} ~ {upper_vlon} \nor {peak_vlon} +{u-0} -{0-l}')
# Out:
# vlon: -177.21135145256022 ~ -18.099129542817707
# or -95.93969922848886 +77.84056968567117 -81.27165222407135

# %% [markdown]
# Jul 24 run
#
# lc0
#
# LX-T: vlon: 89.43141228084255 ~ -46.250504279657264
# or -143.9960655203451 +97.74556124068783 -126.57252219881234
#
# YSZ-T: vlon: -141.8496095510289 ~ -43.29586270933248
# or -83.79082390905354 +40.49496119972107 -58.05878564197534
#
# Mgas-T: vlon: -153.49072270469134 ~ 13.225381389167097
# or -84.01131564453061 +97.23669703369771 -69.47940706016074
#
# lc1
#
# LX-T: vlon: -65.98375790311272 ~ 131.29995207954778
# or 71.97690422892904 +59.323047850618735 -137.96066213204176
#
# YSZ-T: vlon: 70.95657399614925 ~ -137.4973951980396
# or 155.9725140443487 +66.53009075761166 -85.01594004819945
#
# Mgas-T: vlon: -29.790893922482155 ~ 130.4462953632585
# or 72.02985784596908 +58.4164375172894 -101.82075176845122

# %%
# # Most probable direction in 3d distribution
# hist3d, edges = np.histogramdd(flat_samples[:,:3], bins=20, range=None, density=None, weights=None)
# peak_ubf, peak_vlon, peak_vlat = np.where(hist3d==hist3d.max())
# peak_ubf = edges[0][peak_ubf][0]
# peak_vlon = edges[1][peak_vlon][0]
# peak_vlat = edges[2][peak_vlat][0]
# print(peak_ubf, peak_vlon, peak_vlat)

# %%
import corner
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')

plot_samples = flat_samples.copy()
# plot_samples[:, 1] = (plot_samples[:, 1] - peak_vlon + 180) % 360
plot_samples[:, 1] = cf.lonshift(plot_samples[:, 1], -peak_vlon, radian=False)
plot_samples[:, 0] *= 2 # convert delta to 2delta

# lc = 0
df = pd.read_csv(f'../scripts/H0-dipole-direction-lightcone{lc}.csv')
# relation = f'{yname}-{xname}'
lon = df[df['relation'] == relation]['lon'].values[0]
lat = df[df['relation'] == relation]['lat'].values[0]
var = df[df['relation'] == relation]['2delta'].values[0]


fig = corner.corner(
    plot_samples[:, :3],
    labels=['$2\\delta$', '$\\tilde{{\\phi}}\\,(\\degree)$', '$\\lambda\\,(\\degree)$'],
    quantiles=[0.16, 0.5, 0.84],
    # truths=[var, lon, lat]
    truths=[var, cf.lonshift(lon, -peak_vlon, radian=False), lat], # Mgas-T
    levels=[0.39],
    show_titles=True, 
    title_fmt='.3f',
    title_kwargs={"fontsize": 15},
    label_kwargs={"fontsize": 17},
    smooth=1
)

print(peak_vlon, -peak_vlon+180)

# Extract the axes
labels = {
    'M' : 'M_\\mathrm{{gas}}',
    'T' : 'T',
    'LX': 'L_\\mathrm{{X}}',
    'YSZ': 'Y_\\mathrm{{SZ}}',
}
fig.suptitle(f'${labels[yname]}-{labels[xname]}$', fontsize=20)
plt.savefig(f'/Users/yujiehe/Documents/projects/project-anisotropy/plots/forpaper/result-mcmc-{relation}-lc{lc}.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# -95.93969922848886 275.93969922848885

# %%
np.mean(plot_samples[:, 0]), np.std(plot_samples[:, 0])
# Out:
# (0.014558338468432913, 0.011124789745531462)
