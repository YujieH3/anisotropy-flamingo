# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
plt.style.use("./nice.mplstyle")
from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd

# %% [markdown]
# # One plot to rule them all

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

plt.style.use("./nice.mplstyle")
import pandas as pd
import numpy as np

fig, ax = plt.subplots(3, 2, figsize=(20, 15))
plt.subplots_adjust(hspace=0.1, wspace=0.05)

m = Basemap(projection='hammer', lon_0=0)

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)


files = ['../data/fits/legacy2/scan_best_fit_LX-T_θ75.csv', 
         '../data/fits/legacy2/scan_best_fit_YSZ-T_θ60.csv',
         '../data/fits/legacy2/scan_best_fit_M-T_θ75.csv', 
         '../data/fits/legacy2/scan_best_fit_LX-YSZ_θ75.csv',
         '../data/fits/legacy2/scan_best_fit_LX-M_θ75.csv',
         '../data/fits/legacy2/scan_best_fit_YSZ-M_θ75.csv',
        ]

titles = ['$L_\\mathrm{{X}}-T\\quad\\theta=75\\degree$',
          '$Y_\\mathrm{{SZ}}-T\\quad\\theta=60\\degree$',
          '$M_\\mathrm{{gas}}-T\\quad\\theta=75\\degree$',
          '$L_\\mathrm{{X}}-Y_\\mathrm{{SZ}}\\quad\\theta=75\\degree$',
          '$L_\\mathrm{{X}}-M_\\mathrm{{gas}}\\quad\\theta=75\\degree$',
          '$Y_\\mathrm{{SZ}}-M_\\mathrm{{gas}}\\quad\\theta=75\\degree$',
        ]


idx = 0
for row in ax:
    for subax in row:
        subax.set_xlabel('Longitude')
        subax.set_ylabel('Latitude')
        # Load the data from the file
        df = pd.read_csv(files[idx])
        data = np.array(df['n_sigma']).reshape(90, 90).T
        # Display the data as an image; set the extent of the map
        im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='tab20b', 
                      ax=subax, vmin=-3.5, vmax=3.5)

        cbar = plt.colorbar(im, ax=subax)
        cbar.set_label('Significance ($\\sigma$)', rotation=270, labelpad=20)
        subax.set_title(titles[idx], loc='right')
        idx += 1

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /data1/yujiehe/conda-env/halo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n_sigma'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 43
#      41 # Load the data from the file
#      42 df = pd.read_csv(files[idx])
# ---> 43 data = np.array(df['n_sigma']).reshape(90, 90).T
#      44 # Display the data as an image; set the extent of the map
#      45 im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='tab20b',
#      46               ax=subax, vmin=-3.5, vmax=3.5)
#
# File /data1/yujiehe/conda-env/halo/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /data1/yujiehe/conda-env/halo/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'n_sigma'

# %% [markdown]
# # Separate plots

# %%
df = pd.read_csv('../data/fits/testrun/lightcone0/scan_best_fit_LX-T_θ75.csv')

fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$L_\\mathrm{{X}}-T\\quad\\theta=75\\degree$', loc='right')
plt.show()

# %%
df = pd.read_csv('../data/fits/testrun/lightcone0/scan_best_fit_YSZ-T_θ60.csv')

fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$Y_\\mathrm{{SZ}}-T\\quad\\theta=60\\degree$', loc='right')
plt.show()

# %%
df = pd.read_csv('./data/fits/scan_best_fit_M-T_θ75.csv')

fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$M_\\mathrm{{gas}}-T\\quad\\theta=75\\degree$', loc='right')
plt.show()

# %%
df = pd.read_csv('./data/fits/scan_best_fit_LX-YSZ_θ75.csv')
1
fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$L_\\mathrm{{X}}-Y_\\mathrm{{SZ}}\\quad\\theta=75\\degree$', loc='right')
plt.show()

# %%
df = pd.read_csv('./data/fits/scan_best_fit_LX-M_θ75.csv')

fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$L_\\mathrm{{X}}-M_\\mathrm{{gas}}\\quad\\theta=75\\degree$', loc='right')
plt.show()

# %%
df = pd.read_csv('./data/fits/scan_best_fit_YSZ-M_θ75.csv')

fig = plt.figure(figsize=(10, 4))
m = Basemap(projection='hammer', lon_0=0)

data = np.array(df['n_sigma']).reshape(90, 90).T

lon = np.linspace(-180, 180, 90)
lat = np.linspace(-90, 90, 90)
lons, lats = np.meshgrid(lon, lat)
x, y = m(lons, lats)

# Display the data as an image; set the extent of the map
im = m.imshow(data, extent=[-180, 180, -90, 90], cmap='inferno')

plt.colorbar(im, label='No. of $\\sigma$')
plt.title('$Y_\\mathrm{{SZ}}-M_\\mathrm{{gas}}\\quad\\theta=75\\degree$', loc='right')
plt.show()
