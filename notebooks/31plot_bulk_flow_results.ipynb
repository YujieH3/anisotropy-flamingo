# %%
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')
import pandas as pd
data = pd.read_csv('../data/fits/bulk_flow_lightcone0_all.csv')

# %%
d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==0.17)]
d.sort_values('sigma')
# Out:
#        scaling_relation  zmax    ubf    lon   lat  sigma
# 363964             LX-T  0.17  120.0  120.0 -70.0  0.118
# 363967             LX-T  0.17  120.0  120.0 -55.0  0.118
# 363968             LX-T  0.17  120.0  120.0 -50.0  0.118
# 363974             LX-T  0.17  120.0  120.0 -20.0  0.118
# 363977             LX-T  0.17  120.0  120.0  -5.0  0.118
# ...                 ...   ...    ...    ...   ...    ...
# 401890             LX-T  0.17  570.0 -150.0  20.0  0.130
# 395666             LX-T  0.17  495.0  -80.0  40.0  0.130
# 399271             LX-T  0.17  540.0 -160.0  65.0  0.130
# 400594             LX-T  0.17  555.0 -150.0  20.0  0.130
# 403442             LX-T  0.17  585.0  -80.0  40.0  0.133
#
# [50544 rows x 6 columns]

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.88)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()
