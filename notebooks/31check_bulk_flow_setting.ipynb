# %%
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')
import pandas as pd
data = pd.read_csv('../data/fits/bulk_flow_lightcone0_all.csv')

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$L_\mathrm{{X}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$Y_\mathrm{{SZ}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='YSZ-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$M_\mathrm{{gas}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='M-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %% [markdown]
# # Lightcone 1

# %%
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')
import pandas as pd
data = pd.read_csv('../data/fits/bulk_flow_lightcone1_all.csv')

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$L_\mathrm{{X}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$Y_\mathrm{{SZ}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='YSZ-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$M_\mathrm{{gas}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='M-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['ubf'], d['sigma'], s=3)
        ax.set_xlabel('Bulk flow')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %% [markdown]
# ## The direction?

# %%
import matplotlib.pyplot as plt
plt.style.use('./nice.mplstyle')
import pandas as pd
data = pd.read_csv('../data/fits/bulk_flow_lightcone0_all.csv')

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$L_\mathrm{{X}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['lon'], d['sigma'], s=3)
        ax.set_xlabel('glon')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$L_\mathrm{{X}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='LX-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['lat'], d['sigma'], s=3)
        ax.set_xlabel('glat')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$Y_\mathrm{{SZ}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='YSZ-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['lon'], d['sigma'], s=3)
        ax.set_xlabel('glon')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, figsize=(10, 10), sharex=True, sharey=True)
plt.suptitle('$M_\mathrm{{gas}}-T$', y=0.92)

# Adjust the spacing between plots
plt.subplots_adjust(wspace=0, hspace=0)

zmaxs = data['zmax'].unique()
i = 0
for row in axes:
    ylabel=True
    for ax in row:
        d = data.loc[(data['scaling_relation']=='M-T') & (data['zmax']==zmaxs[i])]
        ax.scatter(d['lon'], d['sigma'], s=3)
        ax.set_xlabel('glon')
        if ylabel:
            ax.set_ylabel('Scatter')
            ylabel = False
        ax.set_title(f'zmax={zmaxs[i]}', fontsize=15, y=0.85)

        i += 1
        if i >= len(zmaxs):
            break
    if i >= len(zmaxs):
        break

plt.show()
